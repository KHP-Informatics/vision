# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.8.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Dense, Input, GlobalMaxPooling1D
from tensorflow.keras.layers import LSTM, Embedding

from tensorflow.keras.models import Model

# %%
#data processing

# %%
df = pd.read_csv('potentially_abuse_V2.csv',encoding='unicode_escape')

# %%
df.head()
# Out:
#    label                                           selftext         role
# 0      1   However my stepfather was intoxicated and ass...  perpetrator
# 1      1  I (27f) have recently escaped an abusive relat...       victim
# 2      1  Is anyone aware of an online support group for...       victim
# 3      1  Has anyone had to show up for the abuser__ con...       victim
# 4      1   There was a fair amount of financial abuse in...      witness

# %%
# drop unnecessary columns
df = df.drop(["role"], axis=1)

# %%
df.head()
# Out:
#    label                                           selftext
# 0      1   However my stepfather was intoxicated and ass...
# 1      1  I (27f) have recently escaped an abusive relat...
# 2      1  Is anyone aware of an online support group for...
# 3      1  Has anyone had to show up for the abuser__ con...
# 4      1   There was a fair amount of financial abuse in...

# %%
# rename columns to something better
df.columns = ['labels', 'data']

# %%
df.head()
# Out:
#    labels                                               data
# 0       1   However my stepfather was intoxicated and ass...
# 1       1  I (27f) have recently escaped an abusive relat...
# 2       1  Is anyone aware of an online support group for...
# 3       1  Has anyone had to show up for the abuser__ con...
# 4       1   There was a fair amount of financial abuse in...

# %%
df["label_numerics"]= df["labels"]
Y = df["label_numerics"].values

# %%
df
# Out:
#      labels                                               data  label_numerics
# 0         1   However my stepfather was intoxicated and ass...               1
# 1         1  I (27f) have recently escaped an abusive relat...               1
# 2         1  Is anyone aware of an online support group for...               1
# 3         1  Has anyone had to show up for the abuser__ con...               1
# 4         1   There was a fair amount of financial abuse in...               1
# ..      ...                                                ...             ...
# 995       0   He told me that he would NEVER lay a finger o...               0
# 996       0   But he told me that he has a problem with alc...               0
# 997       0   The first time he Was drunk and I pissed him ...               0
# 998       1       He dragged me down my hallway into my garage               1
# 999       1  Ok so a close friend is being basically held a...               1
#
# [1000 rows x 3 columns]

# %%
df['b_labels'] = df['labels']
Y = df['b_labels'].values

# %%
#TRAIN TEST SPLIT

# %%
df_train, df_test,Ytrain, Ytest= train_test_split(df['data'], Y, test_size=0.2)

# %%
max_words=2000
tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(df_train)

# %%
sequences_train = tokenizer.texts_to_sequences(df_train)
sequences_test= tokenizer.texts_to_sequences(df_test)

# %%
sequences_train
# Out:
# [[6, 118, 10, 512, 352, 4, 65, 663, 253, 4, 664, 2, 6, 102, 9, 4, 1023],
#  [254, 41, 141, 9, 56, 353, 21, 57, 227, 5, 119, 23, 45],
#  [414, 25, 276, 127, 61, 1, 69, 26, 9, 4, 23, 255],
#  [8, 134, 16, 158, 103, 78, 256],
#  [1, 91, 104, 66, 70, 3, 228, 21, 83, 513],
#  [150,
#   59,
#   1,
#   193,
#   665,
#   92,
#   13,
#   6,
#   33,
#   15,
#   142,
#   3,
#   7,
#   12,
#   4,
#   65,
#   2,
#   12,
#   4,
#   277,
#   54,
#   514,
#   185,
#   5,
#   213,
#   71],
#  [4, 105, 14, 1024, 7, 13, 42, 48, 3, 47, 79, 24, 414, 229],
#  [1025, 5, 1026, 9, 86, 1, 1027, 3, 194],
#  [1, 278, 8, 11, 38, 415, 257, 24, 42, 6, 55, 8, 67, 228, 128, 195, 7],
#  [1,
#   5,
#   354,
#   76,
#   176,
#   666,
#   54,
#   69,
#   83,
#   38,
#   23,
#   45,
#   39,
#   1,
#   11,
#   416,
#   2,
#   4,
#   90,
#   11,
#   355],
#  [1,
#   11,
#   667,
#   230,
#   668,
#   2,
#   106,
#   3,
#   279,
#   143,
#   41,
#   1,
#   151,
#   417,
#   49,
#   143,
#   79,
#   1028,
#   1029],
#  [34, 3, 144, 5, 1030],
#  [1,
#   11,
#   418,
#   1031,
#   83,
#   5,
#   515,
#   2,
#   34,
#   5,
#   196,
#   1032,
#   31,
#   1033,
#   42,
#   7,
#   669,
#   1034,
#   8,
#   11,
#   37,
#   3,
#   62,
#   7,
#   186,
#   1,
#   1035,
#   2,
#   62,
#   19,
#   3,
#   47,
#   26,
#   9,
#   15,
#   515],
#  [177, 3, 103, 32, 71, 15, 4, 84, 670, 14, 120, 23],
#  [39, 1, 356, 19, 77, 15, 357, 8, 151, 1036, 24, 30, 671, 280],
#  [141,
#   672,
#   673,
#   11,
#   1037,
#   7,
#   1038,
#   2,
#   281,
#   674,
#   1,
#   50,
#   1039,
#   1040,
#   3,
#   516,
#   92,
#   2,
#   159,
#   16,
#   3,
#   194,
#   92,
#   1041,
#   3,
#   77,
#   11,
#   75,
#   20,
#   1042,
#   40,
#   1,
#   11,
#   160,
#   11,
#   1043,
#   13,
#   1044,
#   5,
#   318,
#   114,
#   2,
#   17,
#   1045,
#   61,
#   39,
#   16,
#   142,
#   158,
#   2,
#   4,
#   675,
#   81,
#   11,
#   517,
#   2,
#   319,
#   13,
#   4,
#   98,
#   3,
#   98,
#   4,
#   518,
#   1,
#   85,
#   1,
#   519,
#   52,
#   128,
#   1,
#   18,
#   419,
#   161],
#  [1, 420, 129, 421, 70, 1, 676, 3, 47, 185, 49, 4, 282],
#  [115, 197, 8, 62, 7, 40, 1, 677, 358, 19, 4, 359],
#  [678, 283, 16, 48, 4, 121, 69, 231, 2, 34, 7, 520, 32, 71],
#  [115, 679, 1, 69, 232, 79, 4, 84],
#  [162, 320, 1046],
#  [1, 116, 10, 5, 1047, 28, 1, 73, 417, 16, 68, 1048],
#  [18, 419, 81, 14, 10, 6, 360, 284, 9, 45],
#  [57, 1049, 680],
#  [8,
#   106,
#   7,
#   15,
#   8,
#   50,
#   67,
#   681,
#   5,
#   1050,
#   20,
#   7,
#   2,
#   15,
#   8,
#   50,
#   67,
#   93,
#   7,
#   46,
#   233,
#   4,
#   682],
#  [4, 361, 121, 362, 3, 44, 234, 42, 7, 10, 94, 130],
#  [1, 321, 5, 258, 521, 37, 6, 1051, 683, 10, 4, 522, 684, 2, 259, 235, 142],
#  [22,
#   85,
#   1052,
#   47,
#   29,
#   15,
#   12,
#   198,
#   81,
#   1053,
#   685,
#   2,
#   1,
#   85,
#   8,
#   81,
#   1,
#   17,
#   58,
#   686,
#   61,
#   18,
#   1054,
#   10,
#   1055],
#  [422, 9, 4, 33, 11, 80, 423, 1056, 687],
#  [131, 1, 11, 80, 1057, 163, 79, 4, 523],
#  [63,
#   122,
#   54,
#   27,
#   145,
#   164,
#   6,
#   688,
#   9,
#   87,
#   2,
#   260,
#   33,
#   1,
#   107,
#   68,
#   689,
#   12,
#   690,
#   20,
#   691,
#   322,
#   94,
#   127],
#  [24,
#   41,
#   5,
#   323,
#   324,
#   16,
#   2,
#   524,
#   99,
#   16,
#   58,
#   1058,
#   3,
#   199,
#   176,
#   56,
#   28,
#   40,
#   16,
#   692,
#   178,
#   63,
#   261,
#   665],
#  [115, 165, 11, 4, 361, 693],
#  [1, 694, 4, 166, 3, 44, 38, 120, 23, 196],
#  [1, 11, 119, 2, 525, 99, 63, 5, 1059, 2, 285, 35, 10, 5, 179],
#  [4, 167, 695, 14, 80, 99, 79, 18, 84, 1060],
#  [4, 108, 14, 1061],
#  [28, 696, 200, 8, 1062, 214, 49, 7],
#  [286, 2, 1063, 93],
#  [1,
#   51,
#   5,
#   236,
#   1064,
#   1065,
#   325,
#   72,
#   54,
#   27,
#   201,
#   1066,
#   40,
#   1,
#   28,
#   1067,
#   49,
#   6,
#   1068,
#   2,
#   6,
#   202,
#   697,
#   2,
#   1069],
#  [186, 8, 424, 83, 31, 698, 12, 425, 237, 67, 3, 44, 686, 158],
#  [1,
#   28,
#   287,
#   426,
#   1,
#   1070,
#   254,
#   77,
#   3,
#   52,
#   48,
#   4,
#   180,
#   107,
#   116,
#   12,
#   89,
#   121,
#   1071,
#   36,
#   288,
#   289,
#   7,
#   363,
#   13,
#   215,
#   253,
#   5,
#   197,
#   46,
#   146],
#  [100, 4, 102, 699, 146, 1072, 83, 6, 526],
#  [28, 5, 165, 71, 4, 64, 11, 290, 2, 1, 11, 1073],
#  [700, 1, 11, 1074, 5, 291, 135, 20, 4, 1075],
#  [16, 11, 701, 2, 179, 2, 364, 15, 55, 1, 1076, 1077],
#  [1, 203, 204, 49, 292, 12, 38, 527, 1078],
#  [1, 134, 214, 10, 4, 1079, 24, 8, 151, 109, 3, 145, 74],
#  [4, 64, 34, 7, 61, 702],
#  [1, 107, 88, 187],
#  [43, 168, 216, 10, 217, 131, 57, 188, 293, 217, 13, 6, 189, 76],
#  [1, 117, 67, 1080, 12, 87, 33, 114],
#  [427, 428, 429, 430, 703, 81, 14, 261, 9, 33, 2, 704, 144, 19, 528],
#  [1, 129, 421, 70, 1081, 204],
#  [10, 6, 205, 177, 32, 43, 529, 217, 5, 181, 142],
#  [1, 363, 10, 6, 1082, 431, 13, 78, 59],
#  [1, 117, 25, 365, 4, 90, 37, 182, 32],
#  [1, 366, 3, 193, 4, 705, 1083],
#  [706, 70, 8, 131, 132, 20, 7, 39, 1, 11, 707],
#  [294,
#   5,
#   147,
#   78,
#   1084,
#   2,
#   1,
#   1085,
#   38,
#   176,
#   1086,
#   9,
#   92,
#   49,
#   6,
#   76,
#   1087,
#   2,
#   8,
#   201,
#   31,
#   262],
#  [4,
#   84,
#   1088,
#   62,
#   7,
#   61,
#   6,
#   115,
#   55,
#   5,
#   165,
#   2,
#   5,
#   530,
#   46,
#   5,
#   367,
#   9,
#   263,
#   71],
#  [1,
#   51,
#   28,
#   708,
#   432,
#   9,
#   709,
#   37,
#   16,
#   1,
#   68,
#   51,
#   206,
#   52,
#   1,
#   17,
#   3,
#   1089,
#   89,
#   2,
#   1090,
#   92,
#   2,
#   669,
#   1,
#   710,
#   1,
#   129,
#   110,
#   169],
#  [1, 117, 207, 145, 3, 531, 1, 368, 37, 295, 78, 74, 4, 84, 14, 5, 711, 64],
#  [294, 1091, 8, 85, 8, 50, 47, 68, 415, 2, 1092, 18],
#  [1, 95, 201, 4, 1093, 296, 40, 9, 6, 64, 38, 1094, 532, 1095, 18, 13, 218],
#  [219,
#   197,
#   1,
#   712,
#   3,
#   533,
#   3,
#   194,
#   4,
#   102,
#   433,
#   534,
#   2,
#   194,
#   4,
#   72,
#   67,
#   88,
#   141,
#   220,
#   9,
#   434,
#   158],
#  [63, 1, 285, 35, 1, 713, 22, 14, 38, 120, 23, 118, 3, 435, 7, 2, 4, 166],
#  [8, 95, 297, 3, 190, 280, 39, 1, 11, 714],
#  [28, 369, 4, 264, 2, 1, 370, 35],
#  [60, 30, 152, 26, 715, 535, 15, 6, 153, 34, 25, 119, 179, 20, 5, 536, 716],
#  [61,
#   326,
#   35,
#   12,
#   19,
#   5,
#   147,
#   127,
#   71,
#   154,
#   717,
#   35,
#   3,
#   680,
#   2,
#   16,
#   718,
#   537,
#   3,
#   7],
#  [203, 1, 51, 10, 5, 719, 720, 721, 238, 4, 64, 13, 722],
#  [12, 1096, 2, 538, 1097, 35],
#  [16, 30, 142, 371],
#  [22,
#   436,
#   20,
#   5,
#   1098,
#   539,
#   1099,
#   1100,
#   1101,
#   3,
#   193,
#   6,
#   96,
#   40,
#   22,
#   278,
#   8,
#   297,
#   18,
#   3,
#   193,
#   6,
#   96,
#   79,
#   188,
#   141,
#   723,
#   1102,
#   2,
#   6,
#   33,
#   50,
#   47,
#   200,
#   298,
#   41,
#   22,
#   221],
#  [61, 100, 6, 33, 27, 540, 437],
#  [39, 43, 541, 8, 69, 7, 3, 6, 239, 240, 1, 372, 170, 3, 190, 92, 46, 19],
#  [43,
#   17,
#   438,
#   19,
#   3,
#   44,
#   23,
#   2,
#   5,
#   241,
#   9,
#   5,
#   1103,
#   63,
#   299,
#   9,
#   123,
#   542,
#   180,
#   136,
#   6,
#   32,
#   17,
#   724,
#   19,
#   34,
#   725,
#   1104,
#   12,
#   19],
#  [73,
#   56,
#   373,
#   98,
#   7,
#   327,
#   6,
#   1105,
#   1106,
#   1107,
#   9,
#   6,
#   726,
#   543,
#   374,
#   361,
#   52,
#   4,
#   64,
#   97,
#   10,
#   31,
#   513,
#   1108,
#   163,
#   12,
#   7,
#   2,
#   145,
#   35,
#   3,
#   7,
#   1109,
#   727,
#   439,
#   228,
#   31,
#   728,
#   163,
#   4,
#   726,
#   2,
#   52,
#   15,
#   242,
#   164,
#   198,
#   1110,
#   328,
#   2,
#   50,
#   199,
#   300,
#   287,
#   190,
#   56,
#   48,
#   6,
#   55],
#  [1, 17, 38, 544, 54, 1, 168, 368, 375, 1111, 376, 20, 70, 14, 80, 1112, 99],
#  [53,
#   329,
#   13,
#   122,
#   54,
#   27,
#   38,
#   440,
#   20,
#   77,
#   441,
#   57,
#   56,
#   279,
#   5,
#   87,
#   111,
#   532],
#  [4, 102, 159, 3, 545, 2, 132, 4, 72],
#  [8, 377, 7, 83, 5, 546, 9, 729, 114, 8, 547, 7, 20, 6, 1113],
#  [39, 5, 118, 330, 10, 5, 1114, 9, 33, 2, 442],
#  [4, 108, 14, 222, 2, 120, 23],
#  [122, 1, 66, 14, 80, 99, 2, 1, 378, 1115, 3, 98, 18, 10, 141, 1116, 130],
#  [6, 64, 14, 97, 6, 1117],
#  [36, 368, 37, 31, 301, 171, 2, 265, 33, 57, 331, 164, 6, 291, 135, 1, 321],
#  [1,
#   17,
#   58,
#   548,
#   3,
#   19,
#   10,
#   443,
#   78,
#   24,
#   6,
#   1118,
#   9,
#   6,
#   1119,
#   8,
#   27,
#   34,
#   20,
#   4,
#   730,
#   1120],
#  [549, 5, 213, 71, 4, 444, 81, 731, 54, 1121, 74, 10, 1122, 550, 191],
#  [4, 167, 102, 14, 5, 1123, 9, 262],
#  [77, 52, 1, 52],
#  [302,
#   29,
#   5,
#   1124,
#   1125,
#   1126,
#   60,
#   1127,
#   302,
#   48,
#   124,
#   2,
#   8,
#   14,
#   6,
#   196,
#   1,
#   231,
#   100,
#   26,
#   9,
#   6,
#   1128,
#   172,
#   692,
#   6,
#   1129,
#   6,
#   64,
#   6,
#   118,
#   15,
#   1,
#   445,
#   53,
#   1130,
#   219,
#   155],
#  [53, 68, 366, 150, 59],
#  [1, 51, 5, 147, 32, 26, 2, 1, 68, 137, 3, 303, 332, 1131, 204, 20, 92],
#  [8,
#   69,
#   333,
#   234,
#   42,
#   7,
#   2,
#   1132,
#   3,
#   222,
#   119,
#   33,
#   7,
#   2,
#   446,
#   7,
#   3,
#   1133,
#   48,
#   9,
#   4,
#   447],
#  [1, 448, 10, 5, 119, 2, 120, 23, 45, 13, 136, 732, 32],
#  [4, 108, 551, 19, 1134, 1135, 3, 132, 7],
#  [21, 14, 4, 379, 2, 8, 552, 17, 5, 449],
#  [4, 65, 84, 2, 1, 159, 3, 47, 83, 171, 450, 114, 43, 553],
#  [8, 14, 26, 20, 1136, 2, 27, 1137, 83, 4, 380, 381, 2, 14, 733, 734, 735],
#  [304, 366, 3, 66, 41, 173, 334, 6, 150, 328, 46, 58],
#  [4,
#   81,
#   354,
#   2,
#   1,
#   736,
#   116,
#   10,
#   38,
#   1138,
#   105,
#   737,
#   12,
#   4,
#   121,
#   2,
#   554,
#   2,
#   544,
#   54,
#   17,
#   174,
#   738,
#   2,
#   38,
#   1139,
#   554],
#  [1, 125, 5, 174, 76, 23, 45, 37, 266, 78, 71],
#  [206, 14, 21, 1, 382, 358, 56, 38, 739],
#  [1, 740, 2, 4, 282, 46, 65, 27, 62, 7, 5, 147, 223, 114, 21],
#  [4, 81, 14, 207, 227, 18, 64, 555],
#  [1,
#   66,
#   1,
#   137,
#   3,
#   233,
#   35,
#   24,
#   1,
#   73,
#   52,
#   15,
#   150,
#   59,
#   556,
#   8,
#   288,
#   289,
#   7,
#   1140,
#   305,
#   2,
#   1,
#   382,
#   17,
#   1141,
#   3,
#   112],
#  [741, 2, 95, 1, 1142, 3, 48, 4, 180, 2, 105, 54, 1143, 19, 9, 557, 7],
#  [16, 537, 58, 3, 88, 742, 46, 451],
#  [452, 558],
#  [4, 166, 1144, 48, 1145, 9, 123, 1146, 559],
#  [60,
#   155,
#   43,
#   156,
#   560,
#   42,
#   4,
#   1147,
#   96,
#   2,
#   22,
#   30,
#   1148,
#   2,
#   138,
#   543,
#   4,
#   523,
#   2,
#   335,
#   7],
#  [8, 548, 37, 743, 86, 2, 453, 169],
#  [6,
#   33,
#   11,
#   68,
#   561,
#   28,
#   1,
#   288,
#   112,
#   83,
#   48,
#   6,
#   376,
#   40,
#   1,
#   17,
#   1149,
#   2,
#   129,
#   109,
#   3,
#   383,
#   92,
#   46,
#   224,
#   454],
#  [120, 2, 336, 42, 133, 24, 59, 1, 51, 160, 15, 8, 14, 75, 3, 62, 7],
#  [1150, 322, 3, 19, 1151, 7, 26, 20, 5, 562, 384],
#  [1,
#   129,
#   183,
#   1,
#   73,
#   303,
#   744,
#   455,
#   1,
#   456,
#   24,
#   1,
#   137,
#   5,
#   1152,
#   2,
#   29,
#   182,
#   263,
#   563,
#   1153,
#   46,
#   148,
#   29,
#   15],
#  [41, 224, 27, 141, 208, 564, 1154, 1155, 16],
#  [1,
#   129,
#   66,
#   54,
#   3,
#   110,
#   21,
#   3,
#   24,
#   4,
#   1156,
#   90,
#   1157,
#   9,
#   276,
#   78,
#   134,
#   5,
#   147,
#   86,
#   15,
#   1,
#   183,
#   156,
#   23],
#  [114, 745, 115, 76, 8, 216, 83, 6, 96, 15, 1, 385, 12, 4, 166, 2, 306, 565],
#  [24, 30, 168, 18, 84, 27, 25, 335, 18],
#  [28, 1, 17, 5, 167, 54, 1, 746, 1158, 44, 10, 5, 336, 2, 120, 23, 45],
#  [1, 47, 132, 35, 5, 181, 79, 4, 161],
#  [1, 747, 267, 6, 33, 305],
#  [1, 1159, 116, 10, 5, 182, 320, 566, 12, 12, 37, 355, 748],
#  [73, 56, 98, 7, 1, 51, 1160, 5, 105, 749, 209, 386, 3, 1161, 9, 1162, 1163],
#  [41,
#   1,
#   457,
#   26,
#   12,
#   373,
#   54,
#   82,
#   438,
#   3,
#   44,
#   1164,
#   750,
#   2,
#   60,
#   155,
#   1,
#   47,
#   290,
#   10,
#   6,
#   387,
#   307,
#   42,
#   6,
#   387,
#   55],
#  [28,
#   37,
#   177,
#   32,
#   71,
#   4,
#   65,
#   751,
#   7,
#   3,
#   734,
#   20,
#   1165,
#   155,
#   1,
#   388,
#   752,
#   9,
#   55,
#   10,
#   6,
#   389,
#   100,
#   69,
#   228,
#   10,
#   5,
#   390,
#   458,
#   1166,
#   13,
#   5,
#   165,
#   40,
#   4,
#   277,
#   106,
#   753,
#   15,
#   1,
#   34,
#   1167,
#   92,
#   268,
#   567,
#   1168],
#  [22,
#   27,
#   25,
#   119,
#   62,
#   2,
#   222,
#   99,
#   79,
#   18,
#   544,
#   61,
#   6,
#   459,
#   9,
#   266,
#   2,
#   1,
#   51,
#   30,
#   754,
#   37,
#   16,
#   63,
#   22,
#   34,
#   5,
#   460,
#   390,
#   233,
#   184],
#  [1,
#   34,
#   1169,
#   18,
#   35,
#   2,
#   1170,
#   18,
#   163,
#   2,
#   4,
#   121,
#   152,
#   1171,
#   3,
#   243,
#   77,
#   48,
#   6,
#   755,
#   11,
#   37,
#   2,
#   756,
#   3,
#   4,
#   81,
#   6,
#   757,
#   36,
#   391,
#   18],
#  [1, 107, 116, 10, 6, 96, 1, 11, 99, 10],
#  [1, 125, 4, 64, 136, 103, 32, 71, 59],
#  [1, 370, 35, 12, 4, 23, 65, 103, 127, 71],
#  [16, 25, 539, 32, 21, 213, 61, 1, 125, 4, 64],
#  [1, 11, 295, 46, 266, 12, 4, 133, 461, 9, 1172, 87, 111, 63, 5, 308],
#  [61,
#   1173,
#   1,
#   51,
#   5,
#   261,
#   163,
#   5,
#   76,
#   71,
#   1,
#   17,
#   25,
#   566,
#   35,
#   4,
#   568,
#   2,
#   168,
#   152,
#   3,
#   6,
#   1174,
#   15,
#   21,
#   45,
#   569,
#   3,
#   392],
#  [25, 319, 10, 4, 431, 13, 37, 177, 127, 59],
#  [1, 10, 5, 1175, 255],
#  [2, 4, 244, 11, 1176],
#  [1, 11, 10, 5, 179, 245, 15, 309, 83, 1177, 758, 111, 39, 1, 125],
#  [4,
#   23,
#   90,
#   119,
#   462,
#   7,
#   115,
#   165,
#   2,
#   61,
#   6,
#   570,
#   1,
#   17,
#   321,
#   5,
#   337,
#   135,
#   13,
#   7,
#   2,
#   4,
#   571],
#  [254,
#   77,
#   1,
#   676,
#   3,
#   52,
#   1,
#   216,
#   26,
#   9,
#   4,
#   759,
#   96,
#   3,
#   116,
#   12,
#   4,
#   90,
#   1,
#   117,
#   25,
#   172,
#   13,
#   174,
#   78],
#  [246, 8, 1178, 25, 119, 23, 10, 5, 162, 55],
#  [1,
#   220,
#   9,
#   30,
#   170,
#   3,
#   760,
#   13,
#   198,
#   1179,
#   20,
#   21,
#   61,
#   1,
#   58,
#   269,
#   41,
#   77,
#   1,
#   17,
#   353,
#   1180,
#   63,
#   87,
#   33,
#   61,
#   16,
#   761,
#   225,
#   1181,
#   2,
#   762,
#   58,
#   63,
#   301,
#   1182,
#   3,
#   77,
#   572,
#   17,
#   353],
#  [1, 11, 463, 10, 4, 573, 79, 4, 431, 763],
#  [1,
#   11,
#   10,
#   5,
#   1183,
#   270,
#   45,
#   1184,
#   4,
#   277,
#   39,
#   464,
#   62,
#   103,
#   78,
#   2,
#   43,
#   310,
#   3,
#   1185,
#   217],
#  [465, 33, 41, 56, 117, 574, 48, 4, 153, 1186, 56, 382, 66, 77, 1, 242, 37],
#  [8, 575, 7, 2, 62, 4, 286, 5, 546, 9, 223],
#  [1, 30, 310, 3, 576, 13, 5, 1187, 29, 21],
#  [427, 428, 429, 430, 703, 81, 14, 261, 9, 33, 2, 704, 144, 19, 1188, 1189],
#  [4, 90, 9, 5, 76, 27, 25, 120, 23, 10, 6, 189],
#  [1190, 13, 56, 2, 98, 56, 12, 198, 390, 458],
#  [43,
#   466,
#   19,
#   577,
#   338,
#   1191,
#   376,
#   2,
#   338,
#   8,
#   466,
#   16,
#   567,
#   1192,
#   13,
#   78,
#   28,
#   1193,
#   34,
#   25,
#   1194,
#   1,
#   569,
#   122,
#   3,
#   1195,
#   376,
#   139,
#   6,
#   578,
#   9,
#   6,
#   15,
#   126,
#   12,
#   6,
#   1196,
#   667,
#   1197,
#   28,
#   15,
#   43,
#   157,
#   764,
#   1198,
#   20,
#   579],
#  [8,
#   11,
#   765,
#   20,
#   6,
#   1199,
#   2,
#   1200,
#   35,
#   28,
#   1201,
#   2,
#   424,
#   766,
#   3,
#   7,
#   2,
#   8,
#   767,
#   7,
#   28,
#   229,
#   1,
#   467,
#   3,
#   6,
#   393,
#   2,
#   93,
#   4,
#   768,
#   68,
#   187],
#  [104,
#   246,
#   4,
#   72,
#   34,
#   5,
#   287,
#   1202,
#   1203,
#   769,
#   10,
#   1204,
#   2,
#   14,
#   1205,
#   325,
#   10,
#   770,
#   458,
#   339,
#   22,
#   107,
#   310,
#   15,
#   22,
#   73,
#   771,
#   19,
#   22,
#   370,
#   16,
#   178,
#   10,
#   1206,
#   1,
#   183,
#   57,
#   1,
#   69,
#   5,
#   1207,
#   49,
#   19,
#   1,
#   11,
#   276,
#   32,
#   176],
#  [13,
#   739,
#   173,
#   69,
#   5,
#   270,
#   1208,
#   103,
#   32,
#   71,
#   2,
#   1,
#   91,
#   112,
#   89,
#   10,
#   29,
#   266,
#   78],
#  [394, 516, 7, 184],
#  [4,
#   81,
#   27,
#   25,
#   10,
#   5,
#   162,
#   1209,
#   45,
#   12,
#   38,
#   23,
#   90,
#   13,
#   6,
#   115,
#   772,
#   32,
#   311,
#   163,
#   276,
#   46,
#   580],
#  [468,
#   1,
#   469,
#   29,
#   22,
#   1210,
#   170,
#   3,
#   41,
#   15,
#   1211,
#   773,
#   1,
#   50,
#   312,
#   26,
#   42,
#   6,
#   1212,
#   9,
#   5,
#   1213,
#   41,
#   1,
#   157,
#   468,
#   1,
#   51,
#   774,
#   325,
#   10,
#   6,
#   105,
#   1214,
#   2,
#   101,
#   218,
#   775],
#  [36, 116, 12, 4, 108, 10, 6, 292, 43, 285, 35, 10],
#  [4, 84, 776, 47, 171, 1215],
#  [1, 777, 35, 3, 68, 672, 1216, 2, 319, 42, 1217],
#  [22,
#   34,
#   25,
#   23,
#   63,
#   581,
#   63,
#   6,
#   155,
#   57,
#   255,
#   10,
#   1218,
#   460,
#   1219,
#   24,
#   6,
#   464,
#   1220,
#   27,
#   470,
#   18,
#   460,
#   1221],
#  [294, 103, 127, 71],
#  [1,
#   582,
#   1222,
#   12,
#   4,
#   72,
#   57,
#   247,
#   10,
#   12,
#   4,
#   100,
#   90,
#   2,
#   174,
#   78,
#   256,
#   8,
#   138,
#   453,
#   7,
#   119,
#   2,
#   120],
#  [1,
#   170,
#   3,
#   385,
#   4,
#   320,
#   10,
#   1223,
#   9,
#   1224,
#   208,
#   20,
#   70,
#   1,
#   73,
#   1225,
#   145,
#   3,
#   531,
#   12,
#   48,
#   9,
#   21],
#  [42, 177, 51, 10, 6, 471, 1, 1226, 184, 83, 6, 1227],
#  [452, 53, 778, 779, 2, 4, 81, 14, 580],
#  [1, 780, 1, 285, 35, 10, 87, 111],
#  [4, 583, 108, 1228, 27, 25, 12, 18, 584, 277, 1229, 13, 37, 266, 32],
#  [8, 14, 1230, 4, 1231, 2, 27, 25, 781, 2, 699, 7],
#  [1,
#   95,
#   1232,
#   10,
#   1233,
#   13,
#   6,
#   162,
#   395,
#   1,
#   175,
#   5,
#   126,
#   5,
#   367,
#   9,
#   32,
#   71,
#   42,
#   5,
#   396,
#   2,
#   43,
#   1234,
#   1235,
#   20,
#   782,
#   2,
#   1236,
#   3,
#   303,
#   5,
#   1237,
#   45],
#  [1, 11, 783, 2, 784, 10, 1238],
#  [465, 171, 33, 49, 121],
#  [1,
#   246,
#   37,
#   585,
#   26,
#   3,
#   143,
#   3,
#   785,
#   37,
#   70,
#   93,
#   1,
#   51,
#   24,
#   1,
#   663,
#   30,
#   1239,
#   192,
#   12,
#   143,
#   63,
#   200,
#   63,
#   586,
#   150,
#   59,
#   318,
#   1,
#   30,
#   210,
#   3,
#   1240,
#   4,
#   786,
#   2,
#   1241,
#   442,
#   9,
#   4,
#   113],
#  [22, 14, 23, 12, 19, 787, 2, 1242, 1243, 1244],
#  [36,
#   17,
#   25,
#   10,
#   38,
#   23,
#   255,
#   13,
#   778,
#   32,
#   59,
#   2,
#   48,
#   9,
#   191,
#   17,
#   1245,
#   49,
#   16],
#  [21,
#   27,
#   142,
#   472,
#   10,
#   6,
#   115,
#   60,
#   76,
#   2,
#   18,
#   673,
#   1246,
#   2,
#   271,
#   1247,
#   234,
#   24,
#   1248,
#   62,
#   7],
#  [549, 439, 322],
#  [8,
#   85,
#   8,
#   50,
#   44,
#   292,
#   79,
#   340,
#   46,
#   103,
#   51,
#   28,
#   15,
#   43,
#   157,
#   788,
#   13,
#   123,
#   679,
#   1249],
#  [4, 84, 159, 3, 132, 2, 1250, 7, 10, 473, 9, 18],
#  [4,
#   180,
#   97,
#   313,
#   8,
#   11,
#   5,
#   124,
#   166,
#   2,
#   1,
#   52,
#   587,
#   89,
#   14,
#   124,
#   10,
#   4,
#   102,
#   173,
#   34,
#   94,
#   124,
#   223,
#   12,
#   19,
#   789,
#   24,
#   56,
#   66,
#   1,
#   11,
#   446,
#   10,
#   21,
#   45,
#   2,
#   1,
#   30,
#   1251,
#   1252,
#   16,
#   455,
#   1,
#   194,
#   16],
#  [1, 137, 208],
#  [36, 368, 37, 31, 301, 171, 2, 265, 33, 57, 331, 164, 6, 291, 135, 1, 321],
#  [28, 4, 23, 65],
#  [1, 88, 707, 2, 1253, 40, 36, 82, 93, 40, 1, 73, 1254, 35, 13, 92, 46, 143],
#  [6, 166, 14, 140, 787, 23, 3, 6, 108, 2, 790, 119, 179],
#  [6, 248, 155, 8, 283, 3, 7, 1255, 56, 66, 564, 67, 93, 56],
#  [1, 137, 208, 20, 77, 1, 73, 52, 40, 1, 791, 61, 8, 14, 26, 9, 474],
#  [115,
#   76,
#   1,
#   17,
#   175,
#   5,
#   118,
#   1,
#   792,
#   724,
#   54,
#   256,
#   309,
#   26,
#   3,
#   44,
#   5,
#   140,
#   588,
#   118],
#  [6, 589, 85, 8, 1256, 1257, 793, 16],
#  [1258, 5, 1259, 50, 98, 12, 4, 794, 1260, 57, 6, 389, 1261],
#  [101, 1262],
#  [8, 132, 6, 262, 26, 9, 7, 13, 38, 1263, 2, 100, 751, 7],
#  [36, 116, 12, 153, 169, 24, 1, 183, 36, 82, 795, 9, 6, 33],
#  [22, 397, 4, 72, 2, 4, 102],
#  [1, 1264, 12, 4, 64],
#  [4,
#   161,
#   11,
#   590,
#   26,
#   9,
#   123,
#   698,
#   1265,
#   2,
#   106,
#   3,
#   112,
#   3,
#   6,
#   748,
#   3,
#   279,
#   1266],
#  [70,
#   134,
#   198,
#   361,
#   121,
#   1267,
#   3,
#   754,
#   37,
#   77,
#   56,
#   34,
#   25,
#   164,
#   1,
#   591,
#   143,
#   3,
#   44,
#   215,
#   1268,
#   195,
#   7],
#  [1, 183, 21, 1269, 9, 5, 796, 253, 128, 24, 53, 797, 3, 798],
#  [59,
#   1,
#   272,
#   8,
#   311,
#   11,
#   475,
#   8,
#   592,
#   93,
#   7,
#   29,
#   8,
#   93,
#   31,
#   476,
#   4,
#   180,
#   139,
#   799,
#   48,
#   110,
#   7,
#   70,
#   124,
#   16,
#   14,
#   15,
#   1,
#   69,
#   26,
#   139,
#   36,
#   362,
#   398,
#   269,
#   15,
#   21,
#   50,
#   117,
#   437,
#   3,
#   111,
#   195,
#   7],
#  [57, 800, 1270, 9, 31, 578, 341, 8, 11, 1271, 1272, 6, 1273, 163, 6, 515],
#  [383,
#   593,
#   13,
#   1274,
#   171,
#   2,
#   260,
#   111,
#   57,
#   78,
#   9,
#   1275,
#   1276,
#   33,
#   15,
#   27,
#   801,
#   7],
#  [206,
#   52,
#   1,
#   107,
#   202,
#   4,
#   65,
#   54,
#   514,
#   185,
#   78,
#   71,
#   57,
#   36,
#   228,
#   7,
#   164,
#   78,
#   9,
#   33,
#   2,
#   249,
#   3,
#   190,
#   7],
#  [2, 399, 35, 400, 2, 1277, 7],
#  [5, 147, 78, 71, 1, 777, 35, 3, 4, 84, 1278, 7],
#  [94, 802, 28, 168, 1, 117, 138, 242, 3, 21, 126],
#  [15, 18, 431, 11, 10, 1279, 2, 22, 469, 451, 29, 22, 34, 25, 742],
#  [1,
#   193,
#   477,
#   594,
#   15,
#   8,
#   342,
#   122,
#   54,
#   330,
#   89,
#   2,
#   36,
#   149,
#   110,
#   19,
#   36,
#   391,
#   7,
#   89],
#  [177, 76, 45, 12, 5, 237, 54, 14, 803, 284, 103, 12, 281, 595, 2, 804],
#  [60, 30, 152, 26, 715, 535, 15, 6, 153, 34, 25, 119, 179, 20, 5, 536, 716],
#  [4, 108, 14, 222, 2, 120, 23],
#  [8, 132, 7, 28, 229, 89, 11, 805, 48, 136, 6, 729],
#  [8,
#   478,
#   15,
#   1,
#   151,
#   541,
#   19,
#   74,
#   2,
#   8,
#   478,
#   70,
#   200,
#   479,
#   8,
#   469,
#   37,
#   280,
#   39,
#   8,
#   132,
#   2,
#   806,
#   7],
#  [89,
#   82,
#   807,
#   808,
#   12,
#   281,
#   2,
#   809,
#   2,
#   168,
#   89,
#   27,
#   5,
#   68,
#   444,
#   596,
#   10,
#   4,
#   597,
#   598,
#   40,
#   9,
#   5,
#   105,
#   810],
#  [22, 27, 5, 599, 79, 425, 196, 15, 14, 59, 811, 812],
#  [600, 253, 5, 76, 83, 6, 1280, 9, 5, 76, 9, 33],
#  [22, 14, 20, 813, 2, 1281, 5, 1282],
#  [1, 17, 25, 10, 38, 23, 45, 13, 6, 189, 146, 32],
#  [8, 27, 463, 7, 5, 367, 9, 223],
#  [302, 25, 205, 146, 78, 61, 1, 125, 4, 64],
#  [1,
#   125,
#   4,
#   292,
#   205,
#   146,
#   78,
#   71,
#   343,
#   273,
#   4,
#   23,
#   65,
#   90,
#   40,
#   15,
#   11,
#   6,
#   130,
#   4,
#   1283,
#   106,
#   7,
#   3,
#   52,
#   16,
#   10,
#   135,
#   3,
#   47,
#   26,
#   9,
#   4,
#   1284,
#   45],
#  [477, 29, 4, 113, 14, 60, 601, 1285, 1286],
#  [1, 125, 5, 245, 9, 87, 111, 2, 11, 814, 5, 291, 135],
#  [1,
#   73,
#   815,
#   20,
#   143,
#   13,
#   128,
#   2,
#   1,
#   17,
#   1287,
#   602,
#   63,
#   38,
#   816,
#   15,
#   1,
#   73,
#   1288,
#   20,
#   4,
#   401],
#  [8, 1289, 103, 1290, 1291, 817, 139, 1292, 818, 60, 3, 280],
#  [1, 69, 5, 1293, 1294, 2, 8, 1295, 752],
#  [819, 820, 4, 161, 14, 231, 12, 182, 571],
#  [4,
#   23,
#   65,
#   14,
#   250,
#   26,
#   9,
#   821,
#   20,
#   822,
#   21,
#   1296,
#   28,
#   6,
#   822,
#   1297,
#   1298,
#   3,
#   19,
#   823,
#   7],
#  [43,
#   156,
#   824,
#   2,
#   69,
#   1299,
#   1300,
#   3,
#   396,
#   123,
#   202,
#   13,
#   60,
#   425,
#   24,
#   68,
#   16,
#   11,
#   48,
#   5,
#   1301],
#  [61,
#   1,
#   11,
#   10,
#   825,
#   278,
#   1,
#   826,
#   4,
#   108,
#   2,
#   11,
#   791,
#   79,
#   18,
#   24,
#   151,
#   66,
#   206],
#  [375, 1302, 5, 598, 3, 17, 5, 215, 1303],
#  [4, 23, 65, 827, 1, 828, 26, 263, 71, 27, 5, 72, 54, 97, 1304, 19],
#  [104, 246, 16, 27, 25, 295, 32, 61, 1, 117, 25, 12, 4, 64],
#  [20,
#   60,
#   9,
#   4,
#   127,
#   178,
#   9,
#   204,
#   1,
#   603,
#   20,
#   1305,
#   1306,
#   3,
#   30,
#   396,
#   35,
#   42,
#   4,
#   711,
#   829,
#   96],
#  [1, 50, 67, 109, 4, 105, 46, 180, 3, 44, 480, 339, 9, 1307, 21, 118],
#  [4, 146, 32, 419, 161, 159, 3, 132, 7, 35, 39, 43, 156, 571],
#  [4, 84, 149, 199, 15, 8, 67, 62, 7, 39, 1, 1308, 19, 37, 31, 344, 602],
#  [1, 310, 15, 6, 481, 383, 593, 11, 215, 1309, 253, 6, 101, 208, 170, 1310],
#  [173,
#   25,
#   272,
#   37,
#   585,
#   26,
#   3,
#   122,
#   37,
#   4,
#   87,
#   111,
#   245,
#   40,
#   1,
#   91,
#   66,
#   77,
#   153,
#   830,
#   3,
#   267,
#   2,
#   1,
#   193,
#   331,
#   15,
#   56,
#   274,
#   110,
#   122,
#   37,
#   198,
#   245],
#  [1,
#   275,
#   20,
#   365,
#   1311,
#   58,
#   329,
#   13,
#   128,
#   1312,
#   2,
#   115,
#   76,
#   1,
#   175,
#   21,
#   196,
#   54,
#   436,
#   4,
#   786,
#   185],
#  [1, 51, 1313, 210, 3, 144, 5, 182, 76, 45, 1314, 12, 265],
#  [16, 604, 29, 302, 28, 200, 1315, 3, 144, 38, 64, 39, 154, 80, 831, 2, 1316],
#  [6, 589, 85, 8, 50, 140, 1317, 793, 16],
#  [1, 832, 21, 833, 3, 5, 167],
#  [6, 258, 14, 341, 36, 747, 834, 16, 19],
#  [8, 399, 35, 534, 1318, 1319, 1320, 139, 1, 1321, 19, 164, 16, 6, 835, 197],
#  [22, 34, 575, 19, 236, 10, 6, 211],
#  [294,
#   53,
#   300,
#   44,
#   75,
#   74,
#   3,
#   4,
#   1322,
#   10,
#   6,
#   770,
#   1323,
#   54,
#   34,
#   188,
#   99,
#   7,
#   4,
#   72,
#   2,
#   4,
#   836,
#   13,
#   32,
#   53,
#   6,
#   1324,
#   565,
#   9,
#   4,
#   482,
#   1,
#   95,
#   17,
#   5,
#   212,
#   81],
#  [4, 161, 54, 34, 5, 1325, 2, 1326, 189, 1327, 10, 4, 236, 37, 148, 8, 134],
#  [63,
#   122,
#   54,
#   27,
#   145,
#   164,
#   6,
#   688,
#   9,
#   87,
#   2,
#   260,
#   33,
#   1,
#   107,
#   68,
#   689,
#   12,
#   690,
#   20,
#   691,
#   322,
#   94,
#   127],
#  [1,
#   160,
#   13,
#   4,
#   1328,
#   57,
#   326,
#   35,
#   12,
#   122,
#   54,
#   27,
#   344,
#   837,
#   2,
#   803,
#   595,
#   2,
#   605,
#   225,
#   552,
#   98,
#   4,
#   245],
#  [452, 314],
#  [1,
#   51,
#   483,
#   41,
#   89,
#   82,
#   141,
#   1329,
#   284,
#   484,
#   1330,
#   46,
#   1331,
#   484,
#   838,
#   1332,
#   15,
#   839,
#   145,
#   35,
#   10,
#   5,
#   1333,
#   1334],
#  [549, 345, 37, 4, 262, 113, 320],
#  [1, 207, 470, 5, 312, 238, 4, 64, 371, 2, 1, 88, 540, 840],
#  [22, 27, 34, 340, 153, 68, 187, 1335, 114, 240, 22, 69, 1336, 1337, 2, 841],
#  [8, 606, 30, 224, 3, 7, 700, 1, 183, 8, 1338, 280, 8, 11, 30, 20, 5, 1339],
#  [1, 30, 170, 5, 307, 3, 1340, 2, 385, 37, 21],
#  [43,
#   17,
#   842,
#   15,
#   73,
#   843,
#   4,
#   485,
#   11,
#   251,
#   2,
#   171,
#   23,
#   195,
#   18,
#   2,
#   7,
#   22,
#   844,
#   7,
#   35,
#   2,
#   377,
#   4,
#   108],
#  [154,
#   34,
#   5,
#   588,
#   189,
#   12,
#   607,
#   2,
#   845,
#   1341,
#   1342,
#   24,
#   11,
#   332,
#   294,
#   13,
#   6,
#   402,
#   422,
#   9,
#   123,
#   45,
#   2,
#   1,
#   11,
#   846,
#   63,
#   162,
#   63,
#   8,
#   11,
#   247,
#   322,
#   10,
#   113,
#   2,
#   58,
#   75,
#   74,
#   3,
#   6,
#   608,
#   2,
#   607],
#  [4,
#   486,
#   403,
#   273,
#   7,
#   16,
#   4,
#   487,
#   36,
#   62,
#   7,
#   46,
#   70,
#   16,
#   4,
#   487,
#   4,
#   277,
#   249,
#   3,
#   190,
#   7,
#   13,
#   227],
#  [2,
#   1,
#   11,
#   28,
#   847,
#   1343,
#   83,
#   183,
#   16,
#   11,
#   48,
#   4,
#   487,
#   2,
#   15,
#   1,
#   11,
#   6,
#   60,
#   10,
#   6,
#   387,
#   39,
#   1,
#   11,
#   6,
#   60,
#   250,
#   62,
#   226,
#   848,
#   609],
#  [39,
#   52,
#   1,
#   47,
#   92,
#   74,
#   39,
#   324,
#   6,
#   1344,
#   610,
#   237,
#   1,
#   201,
#   49,
#   33,
#   145,
#   74,
#   3,
#   7,
#   39,
#   52,
#   1,
#   303,
#   3,
#   88,
#   685,
#   12,
#   4,
#   584,
#   1345],
#  [95, 484, 572, 15, 14, 75, 164, 6, 360, 328, 40, 299, 1346],
#  [849,
#   206,
#   324,
#   16,
#   52,
#   7,
#   29,
#   21,
#   6,
#   1347,
#   1348,
#   34,
#   5,
#   202,
#   13,
#   48,
#   86,
#   850],
#  [4, 264, 11, 1349],
#  [1,
#   106,
#   18,
#   70,
#   8,
#   27,
#   85,
#   70,
#   124,
#   16,
#   469,
#   3,
#   62,
#   7,
#   2,
#   70,
#   8,
#   34,
#   232,
#   7,
#   186,
#   1,
#   1350,
#   42,
#   31,
#   728,
#   13,
#   4,
#   401,
#   113],
#  [8, 85, 41, 1, 112, 3, 6, 851, 8, 1351, 7],
#  [16, 25, 852, 61, 1, 488, 172],
#  [1,
#   30,
#   399,
#   5,
#   1352,
#   76,
#   45,
#   12,
#   5,
#   126,
#   54,
#   1,
#   313,
#   11,
#   4,
#   404,
#   167,
#   2,
#   1353,
#   763],
#  [1,
#   34,
#   101,
#   440,
#   54,
#   11,
#   75,
#   3,
#   44,
#   89,
#   28,
#   1,
#   424,
#   10,
#   853,
#   8,
#   50,
#   44,
#   6,
#   131,
#   60,
#   1,
#   157,
#   611,
#   3],
#  [100, 8, 228, 7, 10, 5, 1354],
#  [219,
#   197,
#   1,
#   712,
#   3,
#   533,
#   3,
#   194,
#   4,
#   102,
#   433,
#   534,
#   2,
#   194,
#   4,
#   72,
#   67,
#   88,
#   141,
#   220,
#   9,
#   434,
#   158],
#  [1, 117, 97, 25, 727, 1355, 37, 54, 1, 289, 83, 4, 113, 854, 4, 202, 113],
#  [8, 25, 120, 23, 13, 78, 2, 78, 24, 1, 67, 313, 8, 11, 1356, 9, 148, 29, 21],
#  [74,
#   10,
#   1357,
#   702,
#   4,
#   81,
#   50,
#   17,
#   301,
#   315,
#   2,
#   281,
#   674,
#   3,
#   6,
#   239,
#   22,
#   50,
#   17,
#   3,
#   112,
#   3,
#   6,
#   389],
#  [39, 1, 110, 19, 1, 432, 9, 80, 9, 80, 99, 8, 855, 7],
#  [4, 84, 2, 1, 17, 25, 553, 13, 443, 32],
#  [1,
#   34,
#   201,
#   4,
#   461,
#   2,
#   221,
#   327,
#   26,
#   8,
#   34,
#   220,
#   7,
#   455,
#   200,
#   256,
#   24,
#   8,
#   50,
#   346,
#   132,
#   7,
#   2,
#   50,
#   612,
#   7,
#   2,
#   34,
#   31,
#   180,
#   612,
#   7,
#   13,
#   218,
#   2,
#   1,
#   448,
#   12,
#   19,
#   13,
#   182,
#   32,
#   207,
#   1,
#   125,
#   2,
#   39,
#   8,
#   856,
#   26,
#   8,
#   405,
#   47,
#   7,
#   74,
#   8,
#   1358,
#   280,
#   10,
#   473,
#   9,
#   7,
#   2,
#   1,
#   17,
#   25,
#   99,
#   525,
#   2,
#   119,
#   61,
#   1,
#   11,
#   295,
#   20,
#   2,
#   178,
#   2,
#   59,
#   53,
#   1359,
#   2,
#   12,
#   5,
#   68,
#   1360,
#   126,
#   15,
#   50,
#   67,
#   681,
#   5,
#   489,
#   20,
#   7,
#   24,
#   156,
#   252,
#   5,
#   181,
#   9,
#   613,
#   40,
#   8,
#   776,
#   68,
#   421,
#   406,
#   1361,
#   9,
#   86,
#   1362,
#   67,
#   25,
#   163,
#   187,
#   169,
#   46,
#   128,
#   2,
#   8,
#   857,
#   7,
#   3,
#   220,
#   9,
#   30,
#   47,
#   136,
#   16,
#   61,
#   406,
#   86,
#   142,
#   32,
#   71,
#   2,
#   8,
#   27,
#   5,
#   229,
#   55,
#   1363,
#   206,
#   1,
#   51,
#   6,
#   130,
#   1,
#   51,
#   2,
#   304,
#   30,
#   220,
#   9,
#   201,
#   254,
#   70,
#   3,
#   614,
#   12,
#   48,
#   9,
#   21],
#  [46,
#   39,
#   36,
#   327,
#   26,
#   56,
#   117,
#   615,
#   3,
#   243,
#   122,
#   454,
#   2,
#   230,
#   849,
#   73,
#   1364,
#   16],
#  [1365, 2, 1366, 13, 6, 1367],
#  [1,
#   1368,
#   13,
#   38,
#   1369,
#   74,
#   100,
#   15,
#   275,
#   858,
#   3,
#   858,
#   12,
#   19,
#   10,
#   1370,
#   20,
#   299,
#   1371],
#  [27,
#   1372,
#   847,
#   616,
#   230,
#   617,
#   3,
#   1373,
#   230,
#   316,
#   73,
#   1374,
#   9,
#   5,
#   316,
#   317,
#   44,
#   859,
#   3,
#   860,
#   1375,
#   1376,
#   6,
#   1377,
#   1378,
#   149,
#   38,
#   1379,
#   1380,
#   44,
#   159,
#   63,
#   1381,
#   4,
#   1382,
#   14,
#   861,
#   115,
#   55,
#   1,
#   391,
#   4,
#   617,
#   8,
#   1383,
#   4,
#   65,
#   26,
#   13,
#   1384,
#   24,
#   8,
#   95,
#   106,
#   7,
#   4,
#   65,
#   11,
#   225,
#   1385,
#   9,
#   5,
#   1386,
#   2,
#   50,
#   67,
#   47,
#   862,
#   2,
#   1,
#   569,
#   3,
#   327,
#   5,
#   130,
#   3,
#   1387,
#   31,
#   1388,
#   33,
#   1389,
#   863,
#   618],
#  [1, 91, 694, 92, 3, 17, 5, 102],
#  [1, 1390, 28, 162, 40, 1, 34, 3, 47, 5, 124, 1391, 20, 4, 65],
#  [1, 51, 6, 64],
#  [8, 1392, 136, 18, 2, 138, 864, 23, 12, 18],
#  [28,
#   271,
#   12,
#   19,
#   13,
#   29,
#   182,
#   32,
#   59,
#   2,
#   1,
#   17,
#   3,
#   116,
#   12,
#   18,
#   40,
#   1393,
#   30,
#   309,
#   456,
#   2,
#   1,
#   107,
#   17,
#   3,
#   112,
#   3,
#   490,
#   4,
#   161,
#   14,
#   29,
#   1394,
#   2,
#   8,
#   27,
#   1395,
#   28,
#   8,
#   68,
#   1396,
#   128,
#   9,
#   77,
#   14,
#   75,
#   20],
#  [1,
#   520,
#   491,
#   168,
#   216,
#   74,
#   3,
#   4,
#   492,
#   619,
#   2,
#   310,
#   3,
#   347,
#   3,
#   194,
#   86,
#   204,
#   12,
#   38,
#   65,
#   277,
#   15,
#   1,
#   448,
#   10,
#   192,
#   12],
#  [101, 1397, 105],
#  [1, 30, 432, 2, 129, 339, 37, 128, 305],
#  [31, 167, 34, 3, 135, 38, 865, 13, 19, 40, 8, 11, 493, 257],
#  [866, 373, 28, 1, 17, 174, 482, 2, 4, 121, 82, 217],
#  [173, 25, 26, 9, 60, 13, 42, 867, 182, 78],
#  [5,
#   367,
#   9,
#   127,
#   71,
#   4,
#   1398,
#   84,
#   11,
#   480,
#   3,
#   474,
#   13,
#   87,
#   494,
#   2,
#   1399,
#   1400],
#  [7, 868, 344, 357, 215, 33],
#  [57, 6, 1401, 9, 123, 620, 59, 174, 1402, 123, 450, 17, 25, 251, 407, 609],
#  [16, 1403, 3, 4, 211, 80, 241],
#  [68, 137, 1404],
#  [4,
#   282,
#   27,
#   97,
#   34,
#   5,
#   495,
#   2,
#   89,
#   27,
#   97,
#   25,
#   5,
#   422,
#   9,
#   7,
#   15,
#   14,
#   160,
#   9,
#   19,
#   24,
#   364,
#   1405,
#   115,
#   76,
#   21,
#   495,
#   1406,
#   215,
#   1407,
#   2,
#   216,
#   3,
#   735,
#   9,
#   111],
#  [172, 14, 6, 245, 1, 11, 1408, 1, 51, 10, 38, 23, 45, 12, 4, 1409, 72],
#  [1, 34, 5, 140, 140, 561, 316, 9, 1410, 281, 869, 40, 9, 87, 111],
#  [6,
#   105,
#   27,
#   85,
#   86,
#   1,
#   88,
#   156,
#   1411,
#   24,
#   8,
#   14,
#   234,
#   39,
#   1,
#   199,
#   15,
#   2,
#   283,
#   53,
#   30,
#   225,
#   1412],
#  [528,
#   1,
#   1413,
#   24,
#   40,
#   21,
#   14,
#   148,
#   1414,
#   3,
#   7,
#   15,
#   1,
#   73,
#   30,
#   870,
#   16,
#   26,
#   317,
#   2,
#   1415],
#  [1, 129, 66, 41, 21, 14, 95, 33],
#  [90, 99, 7, 136, 535, 1416, 9, 92, 20, 380, 381],
#  [1, 28, 287, 160, 150, 59],
#  [4,
#   64,
#   1417,
#   27,
#   25,
#   758,
#   7,
#   1418,
#   2,
#   4,
#   105,
#   226,
#   6,
#   258,
#   555,
#   39,
#   8,
#   871,
#   35,
#   42,
#   4,
#   121,
#   96],
#  [314,
#   14,
#   107,
#   325,
#   49,
#   292,
#   28,
#   1,
#   129,
#   17,
#   6,
#   872,
#   9,
#   30,
#   868,
#   35,
#   3,
#   6,
#   496,
#   3,
#   873,
#   3,
#   122],
#  [1, 51, 5, 1419, 10, 5, 103],
#  [1,
#   107,
#   68,
#   160,
#   37,
#   1420,
#   80,
#   497,
#   861,
#   9,
#   308,
#   33,
#   2,
#   874,
#   24,
#   42,
#   867,
#   8,
#   382,
#   47,
#   498,
#   32,
#   13,
#   6,
#   1421,
#   1422],
#  [8,
#   1423,
#   7,
#   2,
#   39,
#   8,
#   713,
#   6,
#   499,
#   11,
#   1424,
#   138,
#   400,
#   16,
#   184,
#   12,
#   31,
#   1425,
#   1426,
#   186,
#   1,
#   157,
#   417,
#   6,
#   499,
#   615,
#   3,
#   1427],
#  [103, 32, 272, 1, 11, 6, 64],
#  [17, 226, 219, 165, 61, 2, 17, 58, 1428, 3, 5, 875, 10, 48, 15, 55],
#  [1,
#   88,
#   5,
#   1429,
#   9,
#   86,
#   24,
#   1,
#   34,
#   876,
#   9,
#   7,
#   2,
#   19,
#   332,
#   877,
#   86,
#   24,
#   60,
#   878,
#   1,
#   1430,
#   68,
#   524,
#   7,
#   75],
#  [266, 263, 408, 371, 2, 477, 879, 2, 10, 6, 880, 434, 9, 4, 113],
#  [8, 58, 5, 187, 118],
#  [20, 6, 1431, 393, 1432, 5, 881],
#  [30, 77, 6, 1433],
#  [1, 73, 144, 40, 1, 17, 101, 218, 2, 1, 17, 882],
#  [4, 621, 14, 451, 2, 4, 883, 14, 1434],
#  [70,
#   14,
#   16,
#   169,
#   29,
#   21,
#   73,
#   193,
#   325,
#   63,
#   5,
#   884,
#   104,
#   57,
#   811,
#   143,
#   10,
#   622,
#   12,
#   876],
#  [8,
#   11,
#   257,
#   2,
#   297,
#   4,
#   113,
#   12,
#   5,
#   885,
#   2,
#   62,
#   7,
#   481,
#   223,
#   10,
#   6,
#   286,
#   2,
#   886,
#   4,
#   131,
#   887,
#   82,
#   5,
#   888,
#   889],
#  [8, 249, 3, 623, 7, 83, 247, 3, 31, 500],
#  [4, 166, 27, 25, 23, 13, 32, 59],
#  [226, 7, 848, 2, 806, 7],
#  [4, 108, 14, 10, 6, 624, 9, 227, 18, 23, 255, 9, 625, 32],
#  [21, 309, 26, 3, 44, 5, 241, 890, 253, 1, 591],
#  [8, 152, 3, 6, 891, 2, 34, 146, 1435, 9, 1436, 57],
#  [101, 215, 1437],
#  [6, 892, 33, 22, 893, 11, 265, 2, 251],
#  [58,
#   131,
#   11,
#   8,
#   58,
#   894,
#   12,
#   128,
#   36,
#   95,
#   1438,
#   1439,
#   7,
#   8,
#   11,
#   80,
#   626,
#   6,
#   33,
#   27,
#   895,
#   298,
#   61,
#   1,
#   1440,
#   16],
#  [53,
#   28,
#   160,
#   9,
#   6,
#   896,
#   39,
#   36,
#   47,
#   172,
#   2,
#   6,
#   407,
#   2,
#   154,
#   300,
#   1441,
#   2,
#   1442,
#   13,
#   7,
#   58,
#   3,
#   112,
#   3,
#   556,
#   5,
#   1443,
#   2,
#   897,
#   280,
#   184,
#   6,
#   1444,
#   3,
#   1445,
#   29,
#   8,
#   11,
#   93],
#  [43, 17, 61, 125],
#  [1, 88, 29, 5, 1446, 219, 55, 40, 1, 73, 104, 1447, 4, 882],
#  [7, 1448, 1, 51, 5, 1449, 9, 875, 1450, 2, 87, 111],
#  [1,
#   11,
#   483,
#   41,
#   224,
#   342,
#   9,
#   141,
#   1451,
#   15,
#   73,
#   98,
#   12,
#   744,
#   5,
#   1452,
#   1453,
#   1454],
#  [4, 244, 14, 101, 898, 2, 27, 25, 23, 13, 5, 241, 59],
#  [61, 213, 103, 22, 27, 297, 7, 12, 1455, 513],
#  [302,
#   42,
#   6,
#   360,
#   55,
#   29,
#   36,
#   627,
#   19,
#   1456,
#   40,
#   10,
#   29,
#   899,
#   1457,
#   105,
#   613,
#   1,
#   47,
#   1458,
#   42,
#   2,
#   13,
#   19,
#   36,
#   30,
#   91,
#   52,
#   259],
#  [4, 90, 9, 1459, 11, 501, 3, 303, 12],
#  [81, 2, 1, 203, 116, 10, 123, 1460, 1461, 96],
#  [1,
#   293,
#   10,
#   460,
#   1462,
#   12,
#   101,
#   60,
#   3,
#   611,
#   3,
#   628,
#   9,
#   4,
#   23,
#   121,
#   2,
#   23,
#   65],
#  [4, 81, 27, 25, 75, 164, 32, 9, 251],
#  [21, 189, 76, 1, 17, 25, 12, 4, 140, 701, 2, 23, 90],
#  [1, 1463, 13, 98, 2, 8, 69, 160, 2, 289, 7, 112],
#  [53, 95, 900, 40, 154, 5, 261, 9, 1464],
#  [22, 27, 216, 185, 49, 6, 72],
#  [16, 25, 103, 127, 61, 4, 64, 84, 207, 275, 225, 1465],
#  [1466,
#   1467,
#   31,
#   495,
#   2,
#   453,
#   31,
#   209,
#   8,
#   14,
#   140,
#   348,
#   53,
#   58,
#   287,
#   1468,
#   28,
#   7,
#   1469,
#   31,
#   348,
#   1470,
#   30,
#   1471,
#   20,
#   2,
#   20,
#   2,
#   97,
#   1472,
#   629,
#   343,
#   104,
#   272,
#   154,
#   97,
#   329,
#   42,
#   86,
#   1473,
#   225],
#  [1, 117, 67, 313, 9, 557, 18],
#  [1,
#   188,
#   152,
#   172,
#   3,
#   760,
#   61,
#   1,
#   149,
#   44,
#   247,
#   74,
#   12,
#   19,
#   581,
#   53,
#   901,
#   3,
#   279,
#   308,
#   1474,
#   902,
#   20,
#   31,
#   1475,
#   1476,
#   70,
#   630,
#   1,
#   51,
#   1,
#   30,
#   109,
#   3,
#   66,
#   6,
#   624,
#   1,
#   17,
#   4,
#   1477,
#   10,
#   1478,
#   3,
#   116,
#   12,
#   311,
#   2,
#   4,
#   554,
#   10,
#   1479,
#   1480,
#   2,
#   4,
#   95,
#   72,
#   14,
#   903,
#   24,
#   271,
#   733,
#   7,
#   74,
#   2,
#   254,
#   41,
#   904,
#   38,
#   872],
#  [4, 64, 14, 4, 565],
#  [7, 1481, 394, 128, 98, 104, 5, 905, 9, 208, 2, 1482],
#  [16, 138, 178, 1483, 386, 3, 19, 250, 1484],
#  [21,
#   50,
#   44,
#   38,
#   502,
#   1485,
#   24,
#   6,
#   1486,
#   9,
#   19,
#   1487,
#   7,
#   42,
#   38,
#   379,
#   20,
#   4,
#   906,
#   233,
#   50,
#   44,
#   501],
#  [139,
#   1488,
#   331,
#   35,
#   20,
#   70,
#   3,
#   47,
#   26,
#   9,
#   38,
#   23,
#   245,
#   2,
#   89,
#   14,
#   5,
#   181,
#   9,
#   705,
#   20,
#   631,
#   5,
#   603,
#   20,
#   5,
#   632,
#   3,
#   144,
#   29,
#   63,
#   60,
#   9,
#   6,
#   892,
#   830],
#  [28,
#   16,
#   11,
#   205,
#   29,
#   1,
#   30,
#   170,
#   3,
#   907,
#   238,
#   18,
#   54,
#   11,
#   31,
#   162,
#   55,
#   404,
#   167,
#   1,
#   908,
#   83,
#   16,
#   30,
#   28,
#   1,
#   157,
#   17,
#   19,
#   139,
#   95,
#   93,
#   21,
#   237],
#  [43, 117, 25, 101, 192, 13, 205, 443, 78, 2, 8, 25, 909, 13, 205, 146],
#  [4,
#   605,
#   2,
#   315,
#   27,
#   25,
#   68,
#   187,
#   364,
#   6,
#   633,
#   2,
#   80,
#   10,
#   5,
#   45,
#   15,
#   1489,
#   179,
#   39,
#   56,
#   82,
#   634,
#   315,
#   2,
#   605,
#   324,
#   58,
#   98],
#  [1,
#   17,
#   97,
#   1490,
#   4,
#   166,
#   13,
#   6,
#   434,
#   8,
#   27,
#   1491,
#   20,
#   4,
#   108,
#   162,
#   114,
#   1,
#   11,
#   783,
#   8,
#   119,
#   2,
#   222,
#   99,
#   18],
#  [329,
#   74,
#   16,
#   48,
#   1492,
#   3,
#   7,
#   59,
#   2,
#   16,
#   910,
#   70,
#   124,
#   21,
#   118,
#   14,
#   42,
#   1493,
#   58,
#   30,
#   7,
#   24,
#   418,
#   314,
#   10,
#   230,
#   330],
#  [866,
#   558,
#   1,
#   5,
#   354,
#   76,
#   176,
#   237,
#   293,
#   12,
#   18,
#   121,
#   318,
#   1,
#   1494,
#   492,
#   63,
#   5,
#   130,
#   3,
#   1495,
#   218],
#  [8,
#   27,
#   911,
#   9,
#   201,
#   442,
#   61,
#   6,
#   633,
#   62,
#   2,
#   27,
#   25,
#   335,
#   7,
#   10,
#   215,
#   1496,
#   1497],
#  [188,
#   22,
#   334,
#   94,
#   86,
#   3,
#   153,
#   169,
#   2,
#   22,
#   1498,
#   39,
#   22,
#   324,
#   2,
#   1499,
#   16,
#   178,
#   63,
#   5,
#   1500,
#   2,
#   22,
#   1501,
#   7,
#   10,
#   1502,
#   2,
#   1,
#   88,
#   29,
#   22,
#   75,
#   3,
#   62,
#   7,
#   248,
#   55,
#   1,
#   243,
#   18,
#   581,
#   1,
#   160,
#   2,
#   254,
#   77,
#   3,
#   52,
#   41,
#   22,
#   912,
#   7,
#   1,
#   88,
#   29,
#   1,
#   1503,
#   16,
#   3,
#   5,
#   769,
#   61,
#   1,
#   913,
#   123,
#   45,
#   2,
#   59,
#   22,
#   631,
#   1504,
#   9,
#   7,
#   1505,
#   1,
#   445,
#   92,
#   1,
#   129,
#   109,
#   18,
#   3,
#   93,
#   7],
#  [80, 12, 5, 118, 15, 914, 3, 1506, 14, 1507, 910],
#  [302,
#   131,
#   39,
#   1,
#   51,
#   234,
#   415,
#   12,
#   18,
#   37,
#   18,
#   75,
#   1508,
#   238,
#   7,
#   2,
#   1509,
#   4,
#   730,
#   1510,
#   664,
#   409],
#  [851,
#   69,
#   226,
#   2,
#   48,
#   36,
#   134,
#   11,
#   267,
#   6,
#   635,
#   13,
#   5,
#   212,
#   241,
#   2,
#   100,
#   110,
#   4,
#   167,
#   15,
#   274,
#   31,
#   166,
#   420,
#   347,
#   3,
#   93,
#   19],
#  [4,
#   599,
#   69,
#   1511,
#   480,
#   185,
#   40,
#   9,
#   6,
#   64,
#   2,
#   1,
#   109,
#   19,
#   74,
#   154,
#   30,
#   5,
#   212,
#   296,
#   2,
#   1,
#   109,
#   19,
#   2,
#   58,
#   6,
#   64,
#   24,
#   1,
#   107,
#   88,
#   187],
#  [375,
#   44,
#   247,
#   20,
#   4,
#   401,
#   318,
#   1512,
#   44,
#   247,
#   3,
#   5,
#   270,
#   307,
#   12,
#   123,
#   1513,
#   161],
#  [394, 358, 7, 208],
#  [61,
#   1,
#   11,
#   306,
#   4,
#   102,
#   97,
#   132,
#   7,
#   35,
#   10,
#   877,
#   409,
#   39,
#   8,
#   11,
#   415,
#   1514,
#   1515],
#  [1, 388, 32, 210, 3, 47, 390, 98, 13, 4, 64, 54, 14, 1516, 336, 915],
#  [4, 1517, 23, 45, 11, 1518, 251, 1519],
#  [16, 25, 163, 182, 78, 61, 22, 115, 62, 7],
#  [53, 210, 3, 771, 4, 636, 3, 312, 1520, 1521, 185],
#  [104, 343, 19, 10, 4, 113, 1, 107, 503],
#  [36, 110, 4, 72, 15, 36, 519, 98, 18, 186, 22, 151, 47, 5, 410],
#  [637, 2, 1, 17, 25, 217, 13, 205, 103, 32],
#  [1, 69, 26, 9, 21, 119, 23, 45, 205, 146, 32, 71, 59],
#  [916, 6, 917, 9, 146, 263, 8, 638, 4, 499, 10, 472],
#  [16,
#   14,
#   1522,
#   3,
#   199,
#   15,
#   464,
#   354,
#   27,
#   25,
#   588,
#   13,
#   314,
#   2,
#   27,
#   25,
#   1523,
#   3,
#   58,
#   131,
#   1524,
#   1525,
#   2,
#   1526],
#  [4, 244, 14, 101, 898, 2, 27, 25, 23, 13, 5, 241, 59],
#  [2, 53, 58, 269, 41, 15, 11, 6, 150, 328, 3, 52],
#  [254, 77, 1, 274, 52],
#  [8,
#   226,
#   7,
#   49,
#   6,
#   474,
#   240,
#   8,
#   14,
#   20,
#   918,
#   436,
#   26,
#   20,
#   19,
#   13,
#   639,
#   7,
#   2,
#   841,
#   3,
#   190,
#   7],
#  [8, 11, 28, 725, 3, 7, 119, 2, 120, 99, 7, 13, 136, 5, 76],
#  [22, 397, 4, 72, 2, 4, 102],
#  [1, 91, 68, 411, 77, 142],
#  [8, 27, 25, 140, 179, 195, 7],
#  [86,
#   156,
#   919,
#   187,
#   24,
#   1,
#   67,
#   591,
#   19,
#   3,
#   445,
#   7,
#   28,
#   200,
#   3,
#   6,
#   239,
#   240,
#   8,
#   50,
#   93,
#   7,
#   2,
#   1527,
#   3],
#  [1, 34, 5, 181, 9, 1528, 2, 344, 195, 19, 386, 3, 920, 2, 1529],
#  [1, 640, 641, 411, 19, 235, 335, 18],
#  [4, 90, 377, 7, 2, 1, 1530, 2, 467, 2, 59, 4, 1531, 642],
#  [383, 593, 2, 796, 6, 1532, 1533, 4, 64, 12, 31, 1534, 614],
#  [36, 110, 4, 72, 15, 36, 519, 98, 18, 186, 22, 151, 47, 5, 410],
#  [1,
#   4,
#   65,
#   388,
#   6,
#   115,
#   76,
#   136,
#   5,
#   76,
#   59,
#   15,
#   133,
#   566,
#   7,
#   35,
#   100,
#   138,
#   3,
#   222,
#   2,
#   120,
#   99,
#   7,
#   1,
#   152,
#   3,
#   1535,
#   1536,
#   87,
#   111,
#   13,
#   295,
#   32,
#   4,
#   4,
#   244,
#   34,
#   25,
#   34,
#   25,
#   132,
#   1537,
#   1,
#   67,
#   236,
#   1,
#   11,
#   784,
#   67,
#   3,
#   62,
#   5,
#   323,
#   2,
#   1,
#   30,
#   289,
#   18,
#   52,
#   16,
#   67,
#   236,
#   335,
#   18,
#   1538,
#   1539,
#   190,
#   7,
#   10,
#   2,
#   34,
#   29,
#   921,
#   643,
#   1540,
#   2,
#   60,
#   9,
#   6,
#   55,
#   3,
#   922,
#   2,
#   923,
#   5,
#   635,
#   49,
#   18,
#   2,
#   16,
#   275,
#   178,
#   2,
#   1,
#   30,
#   34,
#   345,
#   2,
#   28,
#   1,
#   399,
#   35,
#   1541,
#   3,
#   788,
#   4,
#   374,
#   2,
#   22,
#   134,
#   21,
#   206,
#   1,
#   95,
#   34,
#   924,
#   42,
#   37,
#   580,
#   2,
#   375,
#   110,
#   56,
#   256,
#   1,
#   399,
#   35,
#   227,
#   4,
#   244,
#   24,
#   152,
#   26,
#   172,
#   152,
#   925,
#   18,
#   2,
#   22,
#   926,
#   18,
#   365,
#   21,
#   237,
#   53,
#   1542,
#   271,
#   625,
#   283,
#   86,
#   3,
#   7,
#   46,
#   1543,
#   1544,
#   7,
#   35,
#   2,
#   100,
#   303,
#   927,
#   7,
#   184,
#   927,
#   7,
#   184,
#   10,
#   409,
#   173,
#   67,
#   104,
#   1545,
#   5,
#   118,
#   50,
#   52,
#   36,
#   85,
#   86,
#   3,
#   7,
#   15,
#   15,
#   4,
#   65,
#   54,
#   11,
#   20,
#   539,
#   1546,
#   1547,
#   2,
#   34,
#   921,
#   643,
#   67,
#   236,
#   85,
#   3,
#   7,
#   58,
#   60,
#   55,
#   22,
#   928,
#   259,
#   56,
#   157,
#   504,
#   199,
#   3,
#   5,
#   118,
#   63,
#   5,
#   929,
#   46,
#   5,
#   666,
#   212,
#   196,
#   10,
#   6,
#   10,
#   6,
#   880,
#   586,
#   409,
#   15,
#   123,
#   1548,
#   56,
#   50,
#   104,
#   1549,
#   191,
#   3,
#   69,
#   3,
#   6,
#   239,
#   240,
#   22,
#   138,
#   1550,
#   23,
#   22,
#   50,
#   30,
#   60,
#   55,
#   1551,
#   20,
#   4,
#   1552,
#   693,
#   2,
#   150,
#   57,
#   22,
#   85,
#   22,
#   478,
#   7,
#   29,
#   1553,
#   68,
#   1554,
#   2,
#   100,
#   1555,
#   2,
#   152,
#   74,
#   29,
#   10,
#   21,
#   1556,
#   328,
#   110,
#   7,
#   15,
#   22,
#   175,
#   930,
#   42,
#   839,
#   17,
#   1557,
#   20,
#   18,
#   1558,
#   22,
#   175,
#   930,
#   370,
#   35,
#   12,
#   7,
#   644,
#   370,
#   35,
#   5,
#   212,
#   241,
#   26,
#   172,
#   13,
#   5,
#   165,
#   46,
#   146,
#   57,
#   15,
#   505,
#   242,
#   7,
#   24,
#   22,
#   85,
#   271,
#   332,
#   16,
#   40,
#   1,
#   221,
#   17,
#   6,
#   1559,
#   3,
#   931,
#   18,
#   52,
#   16,
#   42,
#   6,
#   1560,
#   831,
#   53,
#   106,
#   7,
#   15,
#   22,
#   68,
#   826,
#   7,
#   22,
#   50,
#   29,
#   3,
#   112,
#   74,
#   26,
#   12,
#   7,
#   2,
#   100,
#   932,
#   63,
#   200,
#   55,
#   63,
#   22,
#   157,
#   30,
#   1561,
#   7,
#   41,
#   1562,
#   58,
#   75,
#   74,
#   26,
#   7,
#   2,
#   86,
#   69,
#   298,
#   274,
#   47,
#   479,
#   396,
#   35,
#   60,
#   239,
#   56,
#   347,
#   3,
#   645,
#   7,
#   29,
#   5,
#   1563,
#   1564,
#   77,
#   55,
#   56,
#   11,
#   1565,
#   28,
#   22,
#   11,
#   631,
#   5,
#   1566,
#   3,
#   347,
#   3,
#   834,
#   77,
#   56,
#   66,
#   100,
#   22,
#   138,
#   335,
#   7,
#   1,
#   17,
#   25,
#   646,
#   646,
#   1,
#   133,
#   175,
#   18,
#   1,
#   646,
#   1567,
#   49,
#   126,
#   341,
#   148,
#   1568,
#   86,
#   3,
#   18,
#   20,
#   1569,
#   30,
#   29,
#   260,
#   374,
#   3,
#   47,
#   18,
#   3,
#   52,
#   86,
#   1,
#   97,
#   17,
#   21,
#   933,
#   148,
#   11,
#   35,
#   1,
#   356,
#   18,
#   3,
#   576,
#   184,
#   6,
#   1570,
#   1571,
#   22,
#   69,
#   408,
#   34,
#   1572,
#   12,
#   18,
#   65,
#   273,
#   7,
#   15,
#   22,
#   134,
#   15,
#   3,
#   190,
#   6,
#   296,
#   20,
#   647,
#   2,
#   505,
#   326,
#   35,
#   12,
#   7,
#   2,
#   1573,
#   2,
#   50,
#   17,
#   934,
#   22,
#   11,
#   178,
#   332,
#   94,
#   12,
#   94,
#   373,
#   1,
#   152,
#   74,
#   2,
#   279,
#   7,
#   49,
#   6,
#   389,
#   201,
#   5,
#   296,
#   10,
#   198,
#   2,
#   16,
#   11,
#   1574,
#   296,
#   306,
#   152,
#   26,
#   296,
#   43,
#   34,
#   5,
#   1575,
#   13,
#   19,
#   13,
#   18,
#   1,
#   68,
#   170,
#   6,
#   296,
#   2,
#   39,
#   1,
#   69,
#   3,
#   6,
#   389,
#   36,
#   36,
#   288,
#   6,
#   884,
#   204,
#   217,
#   2,
#   935,
#   42,
#   7,
#   2,
#   85,
#   52,
#   43,
#   137,
#   3,
#   17,
#   1576,
#   1577,
#   82,
#   308,
#   902,
#   46,
#   148,
#   15,
#   145,
#   35,
#   172,
#   29,
#   63,
#   10,
#   29,
#   741,
#   501,
#   22,
#   504,
#   221,
#   36,
#   66,
#   22,
#   221,
#   66,
#   28,
#   59,
#   36,
#   66,
#   22,
#   134,
#   22,
#   134,
#   15,
#   20,
#   647,
#   2,
#   22,
#   1578,
#   24,
#   56,
#   66,
#   259,
#   235,
#   175,
#   31,
#   684,
#   1579,
#   11,
#   48,
#   66,
#   24,
#   1,
#   69,
#   3,
#   5,
#   239,
#   3,
#   8,
#   249,
#   3,
#   62,
#   7],
#  [133, 55, 1580],
#  [31, 72, 27, 561, 390, 458, 613, 2, 14, 203, 1581, 3, 339, 13, 19],
#  [28, 53, 398, 269, 21, 352, 936, 13, 522],
#  [173,
#   25,
#   250,
#   5,
#   181,
#   9,
#   167,
#   1582,
#   2,
#   1583,
#   20,
#   4,
#   1584,
#   1585,
#   1586,
#   49,
#   1587,
#   7,
#   2,
#   16,
#   11,
#   708,
#   7,
#   26,
#   40,
#   1,
#   91,
#   66,
#   54,
#   406,
#   169,
#   82,
#   2,
#   41,
#   937,
#   1588,
#   3,
#   4,
#   64,
#   10,
#   94,
#   130],
#  [41,
#   1,
#   457,
#   26,
#   12,
#   5,
#   546,
#   9,
#   101,
#   124,
#   1589,
#   2,
#   148,
#   441,
#   3,
#   7,
#   16,
#   149,
#   44,
#   4,
#   487,
#   13,
#   1590,
#   3,
#   1591,
#   412,
#   169],
#  [1,
#   17,
#   21,
#   878,
#   10,
#   268,
#   1,
#   11,
#   1592,
#   80,
#   687,
#   79,
#   19,
#   2,
#   56,
#   73,
#   919,
#   243,
#   7,
#   366,
#   2,
#   407,
#   2,
#   319,
#   13,
#   19,
#   3,
#   433],
#  [43, 938, 3, 1593, 579, 12, 1594, 1595, 24, 36, 221, 339, 37, 6, 316],
#  [10, 6, 189, 213, 8, 27, 232, 31, 65, 26, 472],
#  [1, 51, 346, 1596, 92, 15, 1, 91, 137, 31, 1597],
#  [8, 85, 248, 55, 1, 648, 19, 8, 149, 233, 4, 211],
#  [8,
#   104,
#   297,
#   3,
#   190,
#   4,
#   105,
#   2,
#   180,
#   41,
#   1,
#   125,
#   24,
#   1,
#   107,
#   202,
#   19,
#   5,
#   181,
#   2,
#   21,
#   14,
#   28,
#   229],
#  [89, 11, 202, 697],
#  [369, 11, 5, 601, 1598],
#  [1,
#   391,
#   56,
#   329,
#   42,
#   7,
#   4,
#   682,
#   138,
#   3,
#   1599,
#   1,
#   151,
#   66,
#   77,
#   11,
#   37,
#   3,
#   267,
#   307,
#   56,
#   935,
#   516,
#   24,
#   1,
#   278,
#   15,
#   606,
#   6,
#   316,
#   16,
#   11,
#   131,
#   5,
#   1600,
#   9,
#   55,
#   114,
#   56,
#   50,
#   62,
#   7,
#   10,
#   4,
#   211,
#   311,
#   1,
#   73,
#   193,
#   6,
#   1601,
#   311,
#   1,
#   73,
#   194,
#   56,
#   610,
#   1,
#   228,
#   20,
#   94,
#   1602,
#   2,
#   5,
#   1603,
#   20,
#   4,
#   211,
#   41,
#   1,
#   156,
#   12,
#   224,
#   454,
#   36,
#   873,
#   20,
#   70,
#   1,
#   1604,
#   12,
#   412,
#   1605,
#   24,
#   3,
#   56,
#   1,
#   11,
#   97,
#   30,
#   1606],
#  [168,
#   163,
#   5,
#   1607,
#   8,
#   69,
#   333,
#   234,
#   42,
#   7,
#   40,
#   1,
#   488,
#   5,
#   1608,
#   9,
#   92,
#   20,
#   5,
#   147,
#   380,
#   381,
#   447,
#   1,
#   17],
#  [4, 166, 14, 1609, 2, 4, 72, 14, 1610],
#  [8, 85, 248, 55, 1, 648, 19, 8, 50, 52, 148, 298],
#  [57,
#   174,
#   32,
#   9,
#   33,
#   119,
#   1,
#   17,
#   497,
#   345,
#   568,
#   3,
#   44,
#   1611,
#   2,
#   26,
#   9,
#   21,
#   196,
#   113,
#   939,
#   56,
#   533],
#  [4, 102, 159, 3, 545, 2, 132, 4, 72],
#  [4, 404, 167, 11, 10, 38, 23, 45, 13, 37, 276, 32],
#  [30, 329, 13, 94, 208],
#  [1,
#   68,
#   68,
#   68,
#   68,
#   68,
#   68,
#   68,
#   1612,
#   1,
#   50,
#   17,
#   34,
#   6,
#   1613,
#   139,
#   568,
#   3,
#   279,
#   6,
#   258,
#   20,
#   19,
#   141,
#   9,
#   6,
#   223,
#   8,
#   99,
#   7,
#   24,
#   1,
#   151],
#  [31, 1614, 632, 11, 1615, 3, 44, 1616],
#  [22,
#   823,
#   6,
#   196,
#   5,
#   147,
#   78,
#   57,
#   8,
#   11,
#   626,
#   46,
#   1617,
#   238,
#   314,
#   22,
#   342,
#   798,
#   2,
#   1618],
#  [1,
#   574,
#   21,
#   1619,
#   5,
#   124,
#   241,
#   61,
#   649,
#   2,
#   30,
#   137,
#   3,
#   785,
#   150,
#   59,
#   28,
#   1,
#   640,
#   940,
#   224,
#   3,
#   574,
#   48,
#   9,
#   21],
#  [2, 53, 107, 503],
#  [41,
#   1,
#   69,
#   5,
#   270,
#   1620,
#   8,
#   149,
#   941,
#   16,
#   41,
#   1,
#   17,
#   17,
#   94,
#   270,
#   1621,
#   43,
#   149,
#   941,
#   16,
#   2,
#   1622,
#   143,
#   650,
#   8,
#   857,
#   143],
#  [6, 320, 14, 20, 6, 1623, 7, 15, 1, 470],
#  [359,
#   338,
#   1624,
#   577,
#   338,
#   1625,
#   354,
#   1626,
#   1627,
#   141,
#   124,
#   1628,
#   1629,
#   1630,
#   98,
#   191,
#   21,
#   352,
#   141,
#   1631,
#   1632,
#   1633,
#   46,
#   94,
#   1634,
#   3,
#   47,
#   1635],
#  [1636, 548, 37, 250, 231],
#  [8, 62, 7, 2, 767, 7, 2, 232, 7, 2, 1, 11, 28, 160],
#  [1, 149, 932, 600, 55, 20, 6, 1637, 13, 1638, 2, 44, 215, 1639, 10, 597],
#  [4,
#   942,
#   490,
#   637,
#   583,
#   32,
#   71,
#   1640,
#   212,
#   192,
#   61,
#   100,
#   1641,
#   7,
#   3,
#   1642,
#   15,
#   22,
#   14,
#   6,
#   261,
#   9,
#   671,
#   87,
#   111,
#   79,
#   18,
#   84,
#   2,
#   131,
#   60,
#   153,
#   118,
#   342,
#   16],
#  [4, 759, 30, 1643, 7, 188, 22, 234, 1, 216, 26, 104, 246, 22, 106, 7, 58, 3],
#  [6, 943, 8, 134, 21, 14, 40, 6, 197, 114],
#  [57, 32, 2, 32, 9, 33],
#  [369,
#   94,
#   126,
#   297,
#   191,
#   3,
#   1644,
#   123,
#   96,
#   2,
#   6,
#   130,
#   8,
#   1645,
#   2,
#   31,
#   1646,
#   2,
#   211,
#   1647,
#   1648,
#   15,
#   154,
#   5,
#   187,
#   126,
#   4,
#   72,
#   356,
#   31,
#   338,
#   1649,
#   8,
#   466,
#   2,
#   57,
#   15,
#   22,
#   85,
#   349,
#   1650,
#   15,
#   338],
#  [1,
#   756,
#   26,
#   6,
#   96,
#   2,
#   1651,
#   178,
#   2,
#   59,
#   53,
#   765,
#   10,
#   4,
#   636,
#   30,
#   483,
#   70,
#   412,
#   5,
#   124,
#   45,
#   309,
#   26,
#   29,
#   21],
#  [10, 6, 189, 8, 11, 222, 2, 120, 23],
#  [1, 28, 542, 3, 30, 846, 1652, 2, 30, 116, 29, 21, 13, 6, 1653, 9, 4, 113],
#  [20, 1654, 114, 1655, 155],
#  [4, 404, 167, 159, 3, 457, 26, 12, 21, 126, 311, 732, 32, 71],
#  [1, 125, 4, 23, 45, 40, 1, 34, 62, 1656, 1657],
#  [1, 207, 52, 17, 1658, 9, 31, 1659, 33],
#  [5, 165, 57, 43, 231, 8, 138, 3, 859, 31, 23, 944],
#  [4, 108, 14, 10, 6, 624, 9, 227, 18, 23, 255, 9, 625, 32],
#  [13, 6, 189, 174, 32, 1, 17, 893, 33, 49, 19, 2, 555, 11, 6, 115, 55],
#  [208,
#   945,
#   188,
#   37,
#   340,
#   76,
#   71,
#   4,
#   72,
#   310,
#   1660,
#   44,
#   5,
#   537,
#   440,
#   3,
#   651,
#   1661,
#   1662,
#   42,
#   7,
#   10,
#   6,
#   636,
#   318,
#   1,
#   405,
#   413,
#   20,
#   6,
#   130,
#   3,
#   204,
#   43,
#   204,
#   217],
#  [4, 946, 2, 4, 485, 397, 4, 72, 2, 1],
#  [46, 30, 38, 5, 1663],
#  [13, 205, 146, 32, 8, 27, 120, 947, 7],
#  [1664, 1665, 9, 87, 111, 47, 3, 144, 230, 1666, 24, 58, 7],
#  [4, 65, 84, 99, 7, 13, 32],
#  [203, 1, 51, 10, 5, 719, 720, 721, 238, 4, 64, 13, 722],
#  [904, 652, 48, 9, 4, 218],
#  [22,
#   1667,
#   1668,
#   19,
#   317,
#   10,
#   6,
#   96,
#   39,
#   1,
#   51,
#   42,
#   204,
#   3,
#   112,
#   26,
#   2,
#   47,
#   942],
#  [1669,
#   304,
#   948,
#   13,
#   945,
#   29,
#   21,
#   24,
#   50,
#   1,
#   104,
#   44,
#   1670,
#   3,
#   112,
#   949,
#   1,
#   5,
#   950,
#   76,
#   176,
#   774,
#   634,
#   6,
#   1671,
#   9,
#   4,
#   121,
#   2,
#   16,
#   58,
#   5,
#   282,
#   2,
#   1,
#   88,
#   29,
#   314,
#   149,
#   30,
#   110,
#   7,
#   3,
#   870,
#   26,
#   70,
#   3,
#   312,
#   26,
#   2,
#   1,
#   95,
#   129,
#   109,
#   3,
#   267,
#   5,
#   307,
#   9,
#   122,
#   54,
#   14,
#   80,
#   1672,
#   99,
#   203,
#   653,
#   1,
#   58,
#   305],
#  [175, 258, 17, 1673, 6, 316, 9, 87, 111, 2, 33, 15, 1, 353, 2, 4, 620, 832],
#  [28,
#   16,
#   11,
#   205,
#   29,
#   1,
#   30,
#   170,
#   3,
#   907,
#   238,
#   18,
#   54,
#   11,
#   31,
#   162,
#   55,
#   404,
#   167,
#   1,
#   908,
#   83,
#   16,
#   30,
#   28,
#   1,
#   157,
#   17,
#   19,
#   139,
#   95,
#   93,
#   21,
#   237],
#  [37,
#   103,
#   32,
#   71,
#   1,
#   106,
#   18,
#   1,
#   1674,
#   44,
#   951,
#   10,
#   18,
#   45,
#   1675,
#   268,
#   11,
#   19,
#   639,
#   18,
#   916,
#   6,
#   133,
#   443,
#   78,
#   9,
#   230,
#   45,
#   2,
#   18,
#   1676,
#   6,
#   1677,
#   3,
#   4,
#   96,
#   163,
#   4,
#   146,
#   306,
#   738],
#  [6,
#   133,
#   55,
#   8,
#   11,
#   171,
#   12,
#   7,
#   8,
#   249,
#   3,
#   1678,
#   7,
#   2,
#   641,
#   6,
#   248,
#   155,
#   43,
#   30,
#   952,
#   37,
#   16],
#  [89,
#   27,
#   67,
#   25,
#   5,
#   213,
#   240,
#   36,
#   953,
#   34,
#   94,
#   284,
#   9,
#   444,
#   541,
#   2,
#   16,
#   14,
#   30,
#   5,
#   954,
#   45],
#  [53, 75, 3, 303, 12, 5, 241, 9, 802],
#  [1, 34, 644, 216, 26, 162, 71, 2, 1, 17, 5, 337, 135, 10, 307],
#  [4, 929, 167, 11, 168, 290, 10, 6, 654, 13, 1679, 31, 264, 10, 5, 1680],
#  [1,
#   1681,
#   491,
#   51,
#   203,
#   520,
#   263,
#   408,
#   139,
#   1,
#   51,
#   207,
#   955,
#   49,
#   6,
#   23,
#   102,
#   1682,
#   103,
#   127,
#   71,
#   43,
#   388,
#   6,
#   1683,
#   155,
#   560,
#   418,
#   49,
#   956,
#   35,
#   3,
#   956,
#   184],
#  [64, 1684, 7, 20, 782],
#  [2,
#   8,
#   300,
#   243,
#   70,
#   299,
#   223,
#   1,
#   226,
#   18,
#   2,
#   8,
#   300,
#   1685,
#   26,
#   158,
#   2,
#   1,
#   30,
#   287,
#   160,
#   1,
#   88,
#   28,
#   426,
#   3,
#   17,
#   228,
#   92,
#   10,
#   21,
#   245],
#  [1, 207, 125, 4, 379, 3, 413, 49, 4, 23, 90],
#  [86, 17, 131, 437, 3, 143, 543, 4, 655, 2, 957, 7],
#  [8, 11, 333, 179],
#  [1,
#   73,
#   52,
#   21,
#   305,
#   188,
#   16,
#   198,
#   1686,
#   257,
# ...
#  [14,
#   16,
#   33,
#   3,
#   1872,
#   20,
#   4,
#   655,
#   46,
#   923,
#   7,
#   3,
#   193,
#   7,
#   49,
#   1873,
#   185,
#   364,
#   38,
#   658,
#   154,
#   131,
#   334,
#   16,
#   5,
#   367,
#   223,
#   24,
#   21,
#   471,
#   1,
#   34,
#   3,
#   47,
#   35,
#   1874,
#   13,
#   5,
#   794,
#   1875,
#   2,
#   8,
#   170,
#   3,
#   1876],
#  [21,
#   126,
#   1,
#   159,
#   3,
#   44,
#   180,
#   12,
#   1877,
#   12,
#   156,
#   645,
#   1001,
#   2,
#   16,
#   69,
#   398,
#   1002],
#  [274,
#   17,
#   125,
#   10,
#   6,
#   133,
#   213,
#   39,
#   8,
#   62,
#   7,
#   2,
#   27,
#   7,
#   1878,
#   20,
#   6,
#   393,
#   3,
#   19],
#  [206,
#   1003,
#   6,
#   1879,
#   6,
#   155,
#   57,
#   8,
#   964,
#   7,
#   341,
#   1,
#   17,
#   1880,
#   9,
#   198,
#   262,
#   511,
#   26,
#   9,
#   4,
#   1881,
#   43,
#   792,
#   1882,
#   559],
#  [1,
#   17,
#   4,
#   401,
#   449,
#   12,
#   4,
#   401,
#   1883,
#   2,
#   1,
#   73,
#   116,
#   1884,
#   1,
#   109,
#   343,
#   31,
#   1885,
#   42,
#   48],
#  [173, 97, 529, 12, 4, 72, 1886],
#  [4, 1887, 62, 7, 13, 6, 133, 55, 5, 147, 127, 71],
#  [8, 11, 909, 3, 950, 32, 40, 8, 14, 5, 1888, 64],
#  [1,
#   157,
#   243,
#   77,
#   1,
#   405,
#   1,
#   85,
#   242,
#   86,
#   3,
#   7,
#   29,
#   1,
#   50,
#   44,
#   5,
#   618,
#   261,
#   2,
#   15,
#   4,
#   209,
#   50,
#   392,
#   35,
#   1004,
#   46,
#   343,
#   5,
#   72],
#  [214, 152, 3, 5, 286, 63, 402, 1005, 15, 82, 23, 52],
#  [1,
#   183,
#   1,
#   109,
#   3,
#   521,
#   21,
#   87,
#   33,
#   24,
#   1,
#   129,
#   66,
#   41,
#   16,
#   5,
#   124,
#   1889,
#   40,
#   1,
#   10,
#   4,
#   1890,
#   32,
#   9,
#   492,
#   2,
#   8,
#   1891,
#   13,
#   4,
#   1892,
#   1893,
#   386,
#   3,
#   6,
#   633,
#   1,
#   34,
#   3,
#   1894,
#   4,
#   115,
#   76,
#   9,
#   492,
#   40,
#   9,
#   464,
#   2,
#   1,
#   137,
#   3,
#   1895,
#   21,
#   115,
#   76],
#  [1, 183, 4, 81, 14, 6, 64, 10, 18, 45],
#  [4, 90, 9, 103, 32, 27, 25, 333, 23],
#  [77, 52, 1, 52, 1, 28, 160],
#  [271,
#   1006,
#   1896,
#   37,
#   214,
#   1,
#   52,
#   2,
#   273,
#   7,
#   39,
#   1,
#   1897,
#   3,
#   18,
#   407,
#   42,
#   7,
#   15,
#   53,
#   210,
#   3,
#   623,
#   18],
#  [371, 1, 11, 510, 28, 229, 10, 473, 9, 4, 209, 1, 207, 226, 6, 258],
#  [16, 149, 44, 498, 32, 21, 1898, 15, 1, 11, 350, 3, 413, 38, 23, 45],
#  [8, 283, 21, 40, 39, 43, 82, 560, 8, 855, 7, 3, 433],
#  [101, 1899, 9, 33, 46, 111, 977, 49, 251, 629],
#  [1, 17, 209, 12, 4, 64],
#  [1, 11, 293, 12, 4, 637, 2, 22, 11, 140, 23, 222],
#  [177, 3, 103, 32, 71, 15, 4, 84, 670, 14, 120, 23],
#  [1, 249, 1900, 2, 3, 44, 999, 1, 91, 66, 70, 3, 204, 6, 328],
#  [59,
#   1,
#   317,
#   12,
#   5,
#   1007,
#   621,
#   2,
#   451,
#   989,
#   319,
#   92,
#   3,
#   573,
#   2,
#   210,
#   3,
#   573,
#   355,
#   1901,
#   5,
#   155,
#   40,
#   80,
#   1902,
#   14,
#   225,
#   1903],
#  [97, 507, 19],
#  [1,
#   106,
#   4,
#   121,
#   2,
#   36,
#   183,
#   15,
#   352,
#   150,
#   24,
#   36,
#   91,
#   199,
#   128,
#   3,
#   19,
#   2,
#   30,
#   403,
#   75],
#  [1, 582, 192, 12, 18],
#  [1, 62, 19, 74],
#  [4, 695, 90, 1904, 275, 26, 3, 545, 12, 31, 180, 115, 197],
#  [114, 1, 175, 18, 1, 11, 231, 3, 38, 23, 196, 265],
#  [8,
#   97,
#   242,
#   37,
#   70,
#   8,
#   1905,
#   1,
#   75,
#   3,
#   112,
#   110,
#   122,
#   139,
#   70,
#   8,
#   508,
#   29,
#   1,
#   17,
#   509,
#   46,
#   1906],
#  [1,
#   11,
#   313,
#   9,
#   92,
#   63,
#   6,
#   1907,
#   63,
#   1908,
#   1,
#   66,
#   28,
#   1909,
#   2,
#   73,
#   922,
#   20,
#   1910,
#   1911,
#   41,
#   53,
#   235,
#   420,
#   462,
#   662,
#   323],
#  [3, 6, 351, 54, 17, 209, 2, 17, 3, 385, 1008, 12, 230, 64],
#  [27, 1912, 1913, 595],
#  [36, 368, 37, 31, 301, 171, 2, 265, 33, 57, 331, 164, 6, 291, 135, 1, 321],
#  [1, 68, 51, 366, 1914],
#  [1, 88, 1915],
#  [1, 11, 12, 4, 23, 65, 13, 174, 32],
#  [53, 948, 41, 21, 14, 58, 6, 150, 307, 13, 21, 372],
#  [30, 63, 6, 678, 283],
#  [95, 169, 20, 172, 199, 91, 1916, 83, 153, 1005],
#  [4, 72, 1009, 1010, 14, 203, 10, 38, 23, 45, 12, 18, 84, 95, 1010],
#  [6,
#   133,
#   55,
#   1,
#   175,
#   19,
#   1,
#   424,
#   83,
#   5,
#   1917,
#   384,
#   530,
#   130,
#   818,
#   139,
#   278,
#   48,
#   24,
#   60,
#   118],
#  [819,
#   820,
#   1,
#   51,
#   75,
#   164,
#   60,
#   9,
#   6,
#   1918,
#   1919,
#   9,
#   4,
#   113,
#   2,
#   1,
#   51,
#   1920,
#   3,
#   17,
#   145,
#   26,
#   9,
#   38,
#   23,
#   45],
#  [4, 84, 1921, 7, 40, 8, 283, 1, 556, 19, 3, 17, 1922, 39, 43, 17, 629],
#  [4, 361, 121, 362, 3, 44, 234, 42, 7, 10, 94, 130],
#  [59,
#   53,
#   503,
#   49,
#   21,
#   49,
#   5,
#   162,
#   55,
#   5,
#   1923,
#   5,
#   181,
#   996,
#   2,
#   1,
#   30,
#   91,
#   66,
#   77,
#   3,
#   52],
#  [528,
#   1,
#   51,
#   5,
#   1924,
#   49,
#   6,
#   654,
#   1925,
#   49,
#   1926,
#   2,
#   1,
#   17,
#   529,
#   10,
#   1927,
#   13,
#   5,
#   147,
#   32],
#  [304, 1006, 853, 6, 1928, 9, 33, 2, 70, 913, 35, 214, 11],
#  [8,
#   11,
#   95,
#   797,
#   37,
#   6,
#   657,
#   15,
#   31,
#   65,
#   264,
#   34,
#   5,
#   291,
#   135,
#   238,
#   19,
#   268,
#   357,
#   8,
#   34,
#   101,
#   192,
#   12,
#   230,
#   308],
#  [49, 6, 755, 1929, 43, 69],
#  [427,
#   428,
#   429,
#   430,
#   1930,
#   5,
#   126,
#   779,
#   1931,
#   15,
#   1,
#   491,
#   740,
#   51,
#   1011,
#   14,
#   140,
#   23],
#  [4, 282, 175, 31, 65, 115, 165],
#  [56, 378, 47, 5, 337, 135, 41, 6, 1932, 496, 378, 1933, 6, 118],
#  [53,
#   988,
#   491,
#   1,
#   11,
#   824,
#   42,
#   355,
#   12,
#   5,
#   731,
#   76,
#   176,
#   827,
#   1,
#   34,
#   5,
#   87,
#   111,
#   45,
#   10,
#   6,
#   654,
#   114,
#   6,
#   258,
#   590,
#   7,
#   413,
#   74,
#   3,
#   1934],
#  [1, 952, 37, 16, 158],
#  [94,
#   153,
#   661,
#   57,
#   1011,
#   31,
#   211,
#   36,
#   156,
#   29,
#   44,
#   1935,
#   91,
#   104,
#   144,
#   1936,
#   209,
#   628],
#  [43, 82, 10, 123, 1009, 1937, 2, 17, 25, 231, 13, 37, 5, 76, 2, 530],
#  [1938, 4, 1012, 248, 499, 14, 1939, 87, 33],
#  [383, 1940, 251, 33],
#  [24,
#   8,
#   67,
#   1941,
#   128,
#   42,
#   7,
#   1942,
#   27,
#   8,
#   235,
#   510,
#   6,
#   526,
#   46,
#   480,
#   31,
#   344,
#   26,
#   15,
#   130],
#  [1, 117, 1943, 5, 326, 239],
#  [1,
#   953,
#   25,
#   1013,
#   13,
#   4,
#   379,
#   468,
#   24,
#   1,
#   47,
#   6,
#   1944,
#   74,
#   41,
#   53,
#   814,
#   28,
#   928,
#   68,
#   101,
#   1945,
#   172],
#  [206,
#   52,
#   1,
#   107,
#   109,
#   3,
#   44,
#   12,
#   122,
#   2,
#   1946,
#   122,
#   54,
#   120,
#   2,
#   336,
#   1947,
#   7],
#  [504, 313, 1, 11, 478, 13, 236],
#  [1, 378, 110, 41, 8, 68, 1000, 5, 262, 37, 7, 46, 58],
#  [6, 87, 969, 106, 7, 15, 8, 1948, 596, 2, 36, 106, 7, 15, 16, 149, 47, 298],
#  [1, 252, 5, 140, 229, 55, 511, 3, 531, 12, 77, 142],
#  [8, 11, 1949, 120, 348, 24, 89, 11, 260, 2, 171, 33, 225],
#  [1,
#   11,
#   418,
#   272,
#   37,
#   652,
#   19,
#   74,
#   40,
#   9,
#   70,
#   1950,
#   35,
#   1,
#   51,
#   10,
#   4,
#   286,
#   57,
#   293,
#   12,
#   38,
#   64,
#   13,
#   28,
#   162],
#  [28,
#   43,
#   938,
#   3,
#   153,
#   1951,
#   579,
#   604,
#   29,
#   1952,
#   267,
#   55,
#   3,
#   327,
#   19,
#   40,
#   36,
#   17,
#   299,
#   1953,
#   1954],
#  [1,
#   66,
#   6,
#   45,
#   11,
#   23,
#   2,
#   1,
#   11,
#   718,
#   1955,
#   24,
#   53,
#   483,
#   41,
#   173,
#   470,
#   5,
#   1956],
#  [28, 133, 9, 48],
#  [8, 27, 1957, 99, 351],
#  [4,
#   65,
#   584,
#   254,
#   90,
#   27,
#   5,
#   301,
#   495,
#   2,
#   31,
#   121,
#   2,
#   1,
#   156,
#   435,
#   594,
#   8,
#   11,
#   75,
#   3,
#   420,
#   93,
#   7,
#   41,
#   8,
#   505,
#   75,
#   42,
#   6,
#   1958,
#   8,
#   11],
#  [4, 84, 27, 5, 536, 23, 570, 219, 177, 127],
#  [1, 1014, 17, 168, 1959, 38, 23, 45],
#  [4, 81, 34, 1960, 48, 18, 1961, 2, 1962, 1015, 7],
#  [1,
#   17,
#   38,
#   891,
#   12,
#   6,
#   1963,
#   1964,
#   20,
#   4,
#   906,
#   233,
#   2,
#   53,
#   477,
#   29,
#   53,
#   75,
#   3,
#   47,
#   862],
#  [50,
#   224,
#   17,
#   1965,
#   13,
#   38,
#   837,
#   1,
#   252,
#   12,
#   5,
#   1966,
#   4,
#   65,
#   14,
#   23,
#   2,
#   30,
#   1967,
#   1968,
#   1008,
#   9,
#   123,
#   133,
#   1969,
#   79,
#   80,
#   1970],
#  [905,
#   1971,
#   439,
#   10,
#   4,
#   619,
#   2,
#   1972,
#   16,
#   616,
#   163,
#   15,
#   4,
#   282,
#   65,
#   282,
#   93,
#   7,
#   2,
#   14,
#   59,
#   1973],
#  [173, 25, 325, 4, 1974, 178, 3, 47, 4, 599, 74],
#  [1, 88, 333, 992, 2, 1, 137, 208],
#  [1, 5, 140, 1975, 2, 220, 1976, 118],
#  [1, 203, 10, 5, 316, 1001, 238, 4, 65, 54, 947, 7, 83, 38, 1977],
#  [1, 488, 10, 1978, 2, 169, 89, 85, 6, 781, 50, 44, 494],
#  [1979,
#   6,
#   1980,
#   3,
#   5,
#   1981,
#   384,
#   1016,
#   384,
#   384,
#   1982,
#   2,
#   1983,
#   9,
#   187,
#   1984,
#   256,
#   48,
#   9,
#   5,
#   997,
#   985,
#   365,
#   139,
#   16,
#   48,
#   138,
#   40,
#   1,
#   405,
#   587,
#   8,
#   1985,
#   7,
#   1015,
#   5,
#   562,
#   12,
#   94,
#   237,
#   54,
#   1986,
#   1987,
#   7],
#  [2, 423, 1988, 9, 344, 149, 145, 49, 4, 102, 402, 9, 6, 55, 1989],
#  [1, 50, 17, 334, 128, 13, 19],
#  [24, 53, 42, 1990, 9, 75, 3, 474],
#  [8,
#   508,
#   29,
#   41,
#   1,
#   17,
#   141,
#   380,
#   381,
#   42,
#   48,
#   42,
#   21,
#   239,
#   40,
#   1,
#   488,
#   6,
#   176,
#   933,
#   9,
#   92,
#   100,
#   1,
#   51,
#   242,
#   3,
#   153,
#   169,
#   2,
#   80,
#   1991],
#  [650,
#   564,
#   974,
#   35,
#   6,
#   130,
#   8,
#   966,
#   191,
#   114,
#   349,
#   97,
#   199,
#   154,
#   58,
#   5,
#   1992,
#   118,
#   252,
#   209,
#   221,
#   145,
#   12,
#   5,
#   1993,
#   46,
#   41,
#   1,
#   62,
#   56,
#   100,
#   110,
#   7,
#   48,
#   6,
#   223,
#   1,
#   134,
#   188,
#   29,
#   53,
#   287,
#   1994,
#   486,
#   300,
#   110,
#   6,
#   632,
#   2,
#   6,
#   1995,
#   8,
#   67,
#   68,
#   1996,
#   154,
#   387,
#   2,
#   100,
#   1997,
#   962,
#   29,
#   154,
#   5,
#   124,
#   126,
#   39,
#   8,
#   324],
#  [1,
#   640,
#   104,
#   29,
#   19,
#   1998,
#   7,
#   305,
#   2,
#   1,
#   88,
#   29,
#   304,
#   1999,
#   24,
#   1,
#   378,
#   362,
#   3,
#   289,
#   16,
#   112],
#  [8,
#   62,
#   7,
#   3,
#   7,
#   35,
#   114,
#   20,
#   9,
#   7,
#   2,
#   639,
#   7,
#   2,
#   273,
#   7,
#   8,
#   11,
#   75,
#   3,
#   897,
#   7,
#   10,
#   5,
#   294],
#  [53, 550, 53, 58, 1004],
#  [427,
#   428,
#   429,
#   430,
#   304,
#   1014,
#   160,
#   3,
#   410,
#   84,
#   24,
#   1,
#   66,
#   1,
#   1017,
#   139,
#   1017,
#   385,
#   2,
#   86,
#   9,
#   221,
#   47,
#   479,
#   24,
#   259,
#   301,
#   27,
#   142,
#   61],
#  [104,
#   246,
#   8,
#   330,
#   10,
#   425,
#   500,
#   2,
#   43,
#   17,
#   58,
#   34,
#   192,
#   13,
#   174,
#   32,
#   2,
#   1,
#   91,
#   603,
#   20,
#   19,
#   40,
#   8,
#   11,
#   23,
#   2,
#   1,
#   125,
#   19],
#  [8,
#   356,
#   7,
#   3,
#   457,
#   35,
#   2,
#   7,
#   15,
#   8,
#   50,
#   547,
#   4,
#   359,
#   26,
#   43,
#   116,
#   20,
#   6,
#   393,
#   24,
#   1,
#   151,
#   109,
#   3,
#   2,
#   107,
#   3,
#   4,
#   81],
#  [28, 1, 137, 3, 284, 21, 26],
#  [1, 73, 98, 24, 8, 210, 3, 645, 261, 3, 899, 54, 19],
#  [1, 34, 67, 25, 20, 5, 562, 139, 221, 109, 3, 16, 184],
#  [57, 6, 402, 998, 494],
#  [8, 27, 93, 7, 10, 6, 189, 970, 2, 50, 158],
#  [1, 66, 16, 662, 27, 773, 24, 16, 642],
#  [8,
#   69,
#   10,
#   6,
#   865,
#   42,
#   182,
#   583,
#   51,
#   2,
#   79,
#   177,
#   51,
#   31,
#   578,
#   20,
#   31,
#   359,
#   85,
#   8,
#   11,
#   10,
#   6,
#   982],
#  [1, 116, 10, 5, 710, 2, 21, 284, 9, 33, 441, 219, 153, 155],
#  [8,
#   14,
#   290,
#   2,
#   894,
#   12,
#   326,
#   5,
#   101,
#   192,
#   135,
#   2,
#   87,
#   33,
#   9,
#   5,
#   914,
#   268,
#   274,
#   44,
#   6,
#   757,
#   13,
#   15,
#   60,
#   24,
#   36,
#   131,
#   17,
#   16,
#   63,
#   6,
#   133],
#  [24, 1, 73, 144],
#  [1, 88, 29, 6, 450, 2, 374, 17, 184, 61, 247, 925, 6, 500],
#  [43,
#   17,
#   842,
#   15,
#   73,
#   843,
#   4,
#   485,
#   11,
#   251,
#   2,
#   171,
#   23,
#   195,
#   18,
#   2,
#   7,
#   22,
#   844,
#   7,
#   35,
#   2,
#   377,
#   4,
#   108],
#  [8, 27, 67, 334, 128, 29, 21, 3, 7],
#  [1, 131, 199, 183, 40, 1, 89, 3, 16],
#  [39, 36, 66, 56, 117, 247, 20, 2, 610, 12, 158],
#  [1, 88, 29, 1, 592, 44, 250, 89],
#  [1, 106, 18, 22, 11, 4, 81, 2, 22, 151, 587, 7],
#  [1, 91, 66, 77, 3, 52, 39, 4, 84, 7],
#  [50, 22, 411, 21, 1, 91, 109, 18, 3, 44, 801],
#  [20, 2, 1, 789],
#  [8, 7, 184, 4, 83, 4],
#  [1, 17, 5, 1012, 54, 1, 551, 80, 99],
#  [89, 11, 5, 9, 1018, 33, 10, 6, 45, 268, 3, 602, 6],
#  [4, 108, 14, 10, 5, 179, 45, 12, 5, 257],
#  [20,
#   60,
#   489,
#   8,
#   14,
#   5,
#   140,
#   220,
#   2,
#   118,
#   24,
#   5,
#   212,
#   3,
#   12,
#   4,
#   518,
#   975,
#   39,
#   8,
#   14,
#   634,
#   6,
#   790,
#   8,
#   372,
#   706,
#   46,
#   8,
#   14,
#   23,
#   8,
#   232,
#   18,
#   659,
#   249,
#   3,
#   233,
#   18,
#   655,
#   638,
#   18,
#   359,
#   2,
#   481,
#   2,
#   817,
#   1,
#   34,
#   97,
#   16,
#   26,
#   41,
#   4,
#   486,
#   58,
#   20,
#   647,
#   2,
#   39,
#   148,
#   142,
#   10,
#   4,
#   113,
#   1,
#   157,
#   1019,
#   9,
#   5,
#   187,
#   55,
#   4,
#   518,
#   11,
#   232,
#   659,
#   2,
#   11,
#   252,
#   2,
#   42,
#   6,
#   55,
#   1,
#   151,
#   17,
#   141,
#   440,
#   77,
#   3,
#   52,
#   10,
#   6,
#   1019,
#   461,
#   21,
#   158,
#   142,
#   24,
#   16,
#   11,
#   57,
#   21,
#   461],
#  [57,
#   21,
#   8,
#   11,
#   828,
#   26,
#   2,
#   58,
#   506,
#   3,
#   116,
#   172,
#   305,
#   439,
#   322,
#   3,
#   59,
#   103,
#   256,
#   4,
#   10,
#   821,
#   13,
#   984,
#   2,
#   302,
#   30,
#   7,
#   2,
#   4,
#   2,
#   173,
#   168,
#   497,
#   26,
#   15,
#   14,
#   75,
#   3,
#   44,
#   247,
#   74,
#   10,
#   12,
#   191,
#   39,
#   1,
#   356,
#   4,
#   1020,
#   108,
#   206,
#   22,
#   11,
#   19,
#   74,
#   10,
#   6,
#   96,
#   57,
#   8,
#   462,
#   7,
#   22,
#   85,
#   154,
#   178,
#   608,
#   59,
#   14,
#   332,
#   200,
#   479,
#   2,
#   50,
#   67,
#   93,
#   7,
#   158,
#   2,
#   30,
#   538,
#   949,
#   3,
#   363,
#   13,
#   5,
#   147,
#   127],
#  [90, 2, 1, 82, 179, 195, 959, 153],
#  [4, 23, 65, 288, 144, 7, 317],
#  [137, 5, 130, 26],
#  [1, 780, 1, 285, 35, 10, 87, 111],
#  [1, 656, 21, 149, 158],
#  [22,
#   341,
#   1,
#   73,
#   312,
#   74,
#   2,
#   39,
#   1,
#   106,
#   18,
#   8,
#   62,
#   7,
#   22,
#   30,
#   662,
#   85,
#   176,
#   56,
#   58,
#   3,
#   312,
#   26,
#   2,
#   1,
#   28,
#   1021,
#   2,
#   93,
#   1,
#   129,
#   421,
#   77,
#   1,
#   357,
#   3,
#   52,
#   1,
#   131,
#   416,
#   1,
#   382,
#   44,
#   456,
#   10,
#   174,
#   263],
#  [1, 11, 6, 9, 182, 836, 10, 5, 140, 105],
#  [43, 82, 203, 901, 3, 312, 26, 2, 112, 123, 979, 409],
#  [16, 25, 37, 177, 32, 9, 5, 9, 397],
#  [963],
#  [4,
#   1020,
#   166,
#   4,
#   161,
#   5,
#   212,
#   136,
#   5,
#   213,
#   71,
#   2,
#   1,
#   183,
#   8,
#   149,
#   47,
#   185,
#   12,
#   16],
#  [8, 69],
#  [28,
#   6,
#   126,
#   304,
#   242,
#   37,
#   14,
#   5,
#   2,
#   5,
#   845,
#   8,
#   346,
#   148,
#   2,
#   8,
#   912,
#   4,
#   108,
#   2,
#   660,
#   42,
#   18,
#   8,
#   236,
#   462,
#   4,
#   161,
#   15,
#   126,
#   14,
#   2,
#   4,
#   14,
#   29,
#   177,
#   266,
#   2,
#   8,
#   346,
#   403,
#   273,
#   191,
#   70,
#   879,
#   43,
#   82,
#   2,
#   70,
#   123,
#   166,
#   274,
#   4,
#   166,
#   27,
#   924,
#   2,
#   15,
#   126,
#   342,
#   15,
#   21,
#   642,
#   191,
#   6,
#   402,
#   2,
#   8,
#   14,
#   191,
#   15,
#   60,
#   155,
#   8,
#   14,
#   75,
#   3,
#   190,
#   191],
#  [4,
#   72,
#   14,
#   59,
#   903,
#   2,
#   2,
#   4,
#   482,
#   82,
#   419,
#   2,
#   216,
#   20,
#   10,
#   937,
#   330,
#   24,
#   4,
#   81,
#   54,
#   14,
#   266,
#   14,
#   12,
#   4,
#   72],
#  [4, 105, 159, 3, 62, 7, 2, 36, 156, 5, 181, 298],
#  [1, 736, 553, 49, 4, 64, 10, 2, 11, 350, 3, 112, 651, 101, 192, 168],
#  [16, 294, 42, 133],
#  [4, 14, 6, 23, 60],
#  [41, 1, 5, 291, 135, 46, 47, 19, 290, 13, 87, 494],
#  [123, 108, 27, 106, 7, 13, 852, 37, 6, 90, 179, 944],
#  [1, 856, 6, 657, 8, 11, 273, 7, 37, 412, 86, 357, 16, 567, 5, 601, 614],
#  [1, 11, 260, 463, 79, 5, 105, 749, 39, 1, 11, 140, 306, 2, 84, 342, 21],
#  [8, 10, 219, 45, 1, 17, 3, 623, 122, 83, 272, 8, 5, 124, 126],
#  [214, 28, 501, 186, 60, 197, 8, 31, 20, 7, 2, 62, 7, 12, 5, 10, 4, 883],
#  [1,
#   51,
#   207,
#   124,
#   345,
#   3,
#   6,
#   8,
#   2,
#   8,
#   107,
#   7,
#   622,
#   4,
#   105,
#   67,
#   278,
#   1,
#   11,
#   408],
#  [1, 137, 98, 12, 214, 15, 1, 75, 164],
#  [1, 91, 109, 3, 86, 63, 260, 33, 2, 2, 28, 20, 63, 572, 17, 85, 16, 14],
#  [1, 203, 107, 293, 12, 4, 23, 90],
#  [8, 67, 235, 871, 9, 80, 23, 186, 21, 115, 76],
#  [138,
#   965,
#   38,
#   333,
#   162,
#   395,
#   24,
#   3,
#   47,
#   766,
#   3,
#   6,
#   239,
#   1,
#   475,
#   15,
#   4,
#   675,
#   161,
#   14,
#   75,
#   3,
#   392,
#   35,
#   743,
#   31,
#   65,
#   264],
#  [1021, 37, 1003, 75, 20, 10, 4, 255],
#  [1, 159, 3, 44, 180, 12, 21, 60],
#  [4, 151, 109, 7, 3, 52, 128, 24, 815, 20, 19, 2, 267, 31, 994, 33],
#  [452, 314],
#  [33, 14, 1022, 3, 7, 79],
#  [4, 337, 135, 11, 1013, 369],
#  [1, 17, 25, 582, 178, 49, 48, 447, 2, 17, 101, 1018, 3, 5, 340],
#  [170, 3, 233, 35, 12, 7],
#  [4, 166, 138, 400, 7, 163, 6, 459, 9, 182, 46, 177, 114, 615, 825],
#  [1, 11, 232],
#  [4, 102, 27, 97, 7, 13, 214],
#  [100, 8, 547, 7, 83, 6],
#  [22,
#   12,
#   5,
#   87,
#   33,
#   532,
#   2,
#   36,
#   82,
#   651,
#   28,
#   22,
#   14,
#   75,
#   3,
#   5,
#   1016,
#   12,
#   18,
#   209],
#  [271, 25, 252, 18, 270, 136, 165, 49, 197, 455, 471],
#  [1, 88, 29, 21, 157, 48, 35, 10, 4, 211],
#  [1,
#   216,
#   10,
#   12,
#   5,
#   126,
#   1,
#   175,
#   990,
#   3,
#   47,
#   185,
#   49,
#   4,
#   72,
#   33,
#   1,
#   34,
#   644,
#   192,
#   12,
#   4,
#   102,
#   79,
#   100,
#   386,
#   3,
#   5,
#   9,
#   111,
#   2,
#   525],
#  [4, 72, 14, 298, 253, 16, 604, 2, 1, 5, 181, 9, 86, 15, 142],
#  [5, 1007, 621, 28, 73, 112, 3, 204, 46, 104, 144, 6, 96, 186, 16],
#  [24, 6, 315, 49, 31, 896, 2, 49, 58, 80, 350, 3, 52, 21, 403, 511, 74],
#  [394, 104, 5, 340, 46, 177, 14, 345, 3, 98, 18, 413, 18, 23, 987],
#  [24, 8, 288, 144, 7, 317],
#  [20,
#   155,
#   1,
#   1022,
#   35,
#   6,
#   237,
#   8,
#   20,
#   7,
#   12,
#   2,
#   106,
#   19,
#   15,
#   41,
#   1,
#   156,
#   18,
#   8,
#   194,
#   269,
#   8,
#   69,
#   7,
#   46,
#   5],
#  [360, 284, 9, 658],
#  [4, 981, 161, 416, 575, 7, 13, 407, 42, 4, 108],
#  [4, 264, 2, 1, 17, 25, 217, 136, 146, 32, 2, 17, 62, 5, 1002],
#  [16, 25, 37, 5, 213, 9, 141, 570, 9, 33],
#  [43, 48, 310],
#  [8, 510, 7, 10, 211, 39, 1, 11, 498, 714, 32, 176, 2, 8, 11, 800, 960],
#  [4, 264, 14, 80, 99, 79, 105, 750],
#  [1, 17, 5, 973, 213, 176, 620],
#  [1, 11, 13, 6, 165, 2, 6, 248, 147, 127, 22, 448, 10, 3]]

# %%
sequences_test
# Out:
# [[4, 1460, 84, 11, 4, 2, 8, 514, 185, 10],
#  [4, 72, 2, 958, 82, 511, 3, 98, 7, 47, 4, 374, 2, 6, 296, 2, 144],
#  [371,
#   43,
#   69,
#   83,
#   38,
#   658,
#   2,
#   16,
#   437,
#   3,
#   240,
#   8,
#   1715,
#   5,
#   2,
#   547,
#   16,
#   42,
#   7,
#   2,
#   100,
#   5,
#   212,
#   318,
#   256,
#   8,
#   510,
#   6,
#   526,
#   318,
#   43,
#   156,
#   560],
#  [1, 17, 38, 23, 419, 161, 10, 31, 1874, 2, 5, 675, 81, 10, 18, 1460],
#  [43, 138, 560, 100, 8, 232, 7, 2, 1, 405, 13, 177],
#  [53, 900, 40, 8, 11, 4, 404, 167],
#  [1362, 67, 31, 728, 20, 7, 24, 27, 25, 120, 23, 13, 6, 189, 174, 32, 59],
#  [1,
#   11,
#   483,
#   41,
#   224,
#   27,
#   28,
#   200,
#   1863,
#   12,
#   33,
#   49,
#   5,
#   1162,
#   870,
#   15,
#   36,
#   88,
#   29,
#   47,
#   10,
#   1863,
#   13,
#   273,
#   148,
#   122,
#   134,
#   29,
#   1,
#   205,
#   69,
#   79,
#   4,
#   401,
#   1,
#   221,
#   68,
#   66,
#   77,
#   1572,
#   11,
#   24,
#   1,
#   11,
#   2,
#   157,
#   110,
#   148,
#   11,
#   35,
#   2,
#   36,
#   106,
#   7,
#   3,
#   267,
#   4,
#   2,
#   178,
#   2,
#   36,
#   505,
#   20,
#   42,
#   16,
#   2,
#   41,
#   230,
#   554,
#   221,
#   279,
#   13,
#   143,
#   13,
#   1917,
#   36,
#   762,
#   50,
#   17,
#   446,
#   7,
#   2,
#   134,
#   16,
#   2,
#   7,
#   425,
#   570,
#   12,
#   60,
#   9,
#   4,
#   142,
#   2,
#   1,
#   91,
#   109,
#   3,
#   199,
#   24,
#   1,
#   762,
#   50,
#   17,
#   95,
#   41,
#   1,
#   221,
#   144,
#   2,
#   112,
#   996],
#  [4, 990, 167, 14, 10, 5, 301, 23, 245],
#  [35, 2, 400, 7, 650, 22, 11, 415, 42, 7],
#  [39,
#   43,
#   448,
#   42,
#   13,
#   5,
#   147,
#   127,
#   22,
#   50,
#   37,
#   7,
#   12,
#   4,
#   65,
#   2,
#   36,
#   50,
#   188,
#   1164,
#   35,
#   20,
#   7],
#  [43,
#   34,
#   85,
#   1,
#   202,
#   56,
#   2,
#   435,
#   9,
#   191,
#   469,
#   29,
#   21,
#   157,
#   44,
#   6,
#   1287,
#   45,
#   9,
#   123,
#   330],
#  [59, 22, 27, 5, 15, 10, 18, 2, 18, 82, 727, 970],
#  [1, 204, 364, 21, 633, 22, 324, 58],
#  [8,
#   1668,
#   13,
#   772,
#   127,
#   42,
#   5,
#   55,
#   131,
#   3,
#   145,
#   74,
#   2,
#   627,
#   6,
#   1653,
#   9,
#   6,
#   105,
#   29,
#   262],
#  [318, 1, 747, 15, 8, 11, 23, 195, 244, 174],
#  [162, 395],
#  [8, 14, 29, 5, 5, 444, 126, 2, 53, 30, 5, 28, 1, 30, 378, 19],
#  [177, 263, 114, 745],
#  [136, 6, 32, 8, 50, 26, 3, 18],
#  [101, 180],
#  [16, 14, 130, 225],
#  [1,
#   405,
#   47,
#   19,
#   178,
#   4,
#   489,
#   2,
#   59,
#   16,
#   642,
#   29,
#   5,
#   24,
#   8,
#   69,
#   77,
#   8,
#   170,
#   1,
#   6,
#   499,
#   2,
#   289,
#   19,
#   112],
#  [928, 21, 126],
#  [1, 58, 104, 269, 21, 14, 33, 46, 41, 1, 16, 26, 9],
#  [100, 4, 946, 4, 482, 238, 123, 698, 499, 28, 8, 1674, 47, 10],
#  [24, 60, 757, 60, 9, 123, 180, 11, 1216, 42, 7, 37, 58, 331, 6, 1805, 79],
#  [1370, 11, 184, 386, 3, 464, 2, 31, 270, 632, 667, 11],
#  [4,
#   102,
#   27,
#   25,
#   23,
#   195,
#   7,
#   4,
#   835,
#   113,
#   2,
#   4,
#   108,
#   54,
#   1,
#   117,
#   895,
#   20,
#   40,
#   1,
#   51,
#   12,
#   561,
#   390,
#   458,
#   602,
#   386,
#   3,
#   105,
#   1899,
#   2,
#   95,
#   1410,
#   49,
#   80,
#   99,
#   2,
#   742,
#   79,
#   4,
#   166,
#   63,
#   5,
#   1059,
#   2,
#   22,
#   27,
#   48,
#   9,
#   21,
#   2,
#   2,
#   4,
#   166,
#   54,
#   538,
#   98],
#  [1, 11, 408, 42, 6, 55, 2, 22, 50, 7, 13, 5, 181],
#  [1768,
#   2,
#   4,
#   390,
#   710,
#   14,
#   5,
#   241,
#   48,
#   136,
#   6,
#   307,
#   28,
#   948,
#   41,
#   21,
#   761,
#   631,
#   773,
#   4,
#   518,
#   1921,
#   7,
#   790,
#   2,
#   16,
#   25,
#   215,
#   1215,
#   168],
#  [141, 20, 390, 1280],
#  [101,
#   1600,
#   77,
#   173,
#   249,
#   302,
#   418,
#   97,
#   7,
#   83,
#   281,
#   869,
#   2,
#   100,
#   1,
#   34,
#   3,
#   1020,
#   178,
#   2,
#   347,
#   3,
#   327,
#   409,
#   3,
#   516,
#   92,
#   184],
#  [5, 367, 127, 71, 4, 1370, 902, 58, 1701],
#  [100,
#   1,
#   777,
#   35,
#   3,
#   19,
#   1998,
#   7,
#   146,
#   215,
#   223,
#   57,
#   15,
#   2,
#   16,
#   470,
#   7,
#   88,
#   28],
#  [2, 101, 1600, 70, 229, 16, 14, 1, 73, 433, 1975, 4, 277, 54, 514],
#  [1, 66, 15, 21, 776, 194, 773, 1415],
#  [641,
#   53,
#   93,
#   28,
#   200,
#   79,
#   19,
#   1,
#   52,
#   10,
#   657,
#   445,
#   19,
#   2,
#   1,
#   52,
#   587,
#   4,
#   14,
#   1516,
#   79,
#   4,
#   121,
#   2,
#   1,
#   66,
#   89,
#   82,
#   301,
#   86,
#   4,
#   121,
#   91,
#   66,
#   37,
#   7],
#  [452, 373],
#  [1,
#   91,
#   66,
#   41,
#   21,
#   14,
#   148,
#   1457,
#   2,
#   441,
#   10,
#   1005,
#   24,
#   1,
#   88,
#   29,
#   4,
#   730,
#   27,
#   25,
#   480,
#   185],
#  [304, 203, 10, 5, 162, 45, 2, 4, 637, 14, 80, 99, 79, 18, 161, 119],
#  [8, 11, 690, 20, 6, 657, 15, 1, 1390, 498, 127, 3],
#  [16,
#   470,
#   7,
#   333,
#   2,
#   387,
#   24,
#   1,
#   67,
#   106,
#   19,
#   58,
#   3,
#   7,
#   10,
#   4,
#   573,
#   28,
#   1,
#   911,
#   9,
#   436,
#   6,
#   13,
#   15,
#   60],
#  [8,
#   85,
#   8,
#   469,
#   187,
#   37,
#   214,
#   8,
#   134,
#   2,
#   218,
#   13,
#   563,
#   2,
#   1849,
#   28,
#   1,
#   2,
#   4,
#   157,
#   363,
#   10,
#   6,
#   379,
#   2,
#   58,
#   44,
#   1860,
#   13,
#   5,
#   318],
#  [43, 175, 5, 237, 12, 4, 180, 15, 524, 346, 2, 1112, 79, 18, 419, 81],
#  [73,
#   224,
#   358,
#   141,
#   208,
#   20,
#   70,
#   3,
#   47,
#   136,
#   5,
#   23,
#   65,
#   90,
#   43,
#   11,
#   217,
#   13,
#   276,
#   32,
#   2,
#   700,
#   43,
#   34,
#   38,
#   527,
#   45,
#   1,
#   50,
#   199,
#   20,
#   1795,
#   8,
#   50,
#   47,
#   179,
#   12,
#   7,
#   163,
#   236,
#   5,
#   76,
#   2,
#   8,
#   751,
#   7],
#  [43,
#   378,
#   144,
#   6,
#   96,
#   653,
#   43,
#   17,
#   101,
#   218,
#   2,
#   4,
#   166,
#   14,
#   95,
#   8,
#   1997,
#   339,
#   9,
#   4,
#   72,
#   4,
#   108,
#   600,
#   100,
#   1880,
#   49,
#   653,
#   18],
#  [1, 129, 66, 77, 3, 52],
#  [1, 193, 272, 21, 196, 149, 67, 289, 7, 144],
#  [427, 428, 429, 430, 273, 180, 2, 105, 37, 6],
#  [921, 32, 71, 1, 11, 462, 2, 463, 79, 5, 9],
#  [154, 38, 23],
#  [465, 33, 1, 125, 4, 23, 65, 205, 103, 32, 71],
#  [1,
#   95,
#   497,
#   26,
#   8,
#   131,
#   995,
#   400,
#   18,
#   35,
#   40,
#   18,
#   108,
#   297,
#   3,
#   279,
#   6,
#   851,
#   1352,
#   78,
#   71,
#   2,
#   436,
#   509,
#   9,
#   6,
#   2],
#  [63, 1, 285, 35, 1, 713, 22, 14, 38, 120, 23, 118, 3, 435, 7, 2, 4, 166],
#  [4, 161, 54, 14, 205, 583, 107, 330, 42, 292],
#  [173,
#   97,
#   1142,
#   37,
#   6,
#   33,
#   3,
#   39,
#   1,
#   11,
#   306,
#   40,
#   97,
#   199,
#   1952,
#   228,
#   7,
#   10,
#   5,
#   262,
#   339,
#   292,
#   2,
#   564,
#   47,
#   742,
#   2,
#   33,
#   298],
#  [24,
#   8,
#   106,
#   7,
#   15,
#   8,
#   27,
#   5,
#   1117,
#   12,
#   607,
#   9,
#   2,
#   83,
#   5,
#   301,
#   118,
#   39,
#   8,
#   534],
#  [1, 17, 774, 12, 4, 121, 386, 3, 1405, 13, 5, 213, 59],
#  [650, 4, 166, 524, 7, 3, 15, 239, 8, 1472, 16, 2, 1034, 154, 861],
#  [123,
#   45,
#   27,
#   895,
#   68,
#   954,
#   10,
#   6,
#   189,
#   146,
#   32,
#   39,
#   22,
#   418,
#   6,
#   169,
#   54,
#   156,
#   453,
#   7,
#   222],
#  [1, 11, 228, 83, 6, 386, 3, 6, 33, 15, 11, 79, 119],
#  [2, 1, 117, 249, 3, 279, 4, 518, 28, 299, 223, 371, 2, 22, 30, 403, 6, 279],
#  [314, 273, 7, 302, 58, 4, 776, 194, 16, 433, 557],
#  [4,
#   599,
#   14,
#   203,
#   10,
#   1008,
#   186,
#   1,
#   47,
#   19,
#   74,
#   386,
#   3,
#   6,
#   65,
#   87,
#   111,
#   238,
#   7],
#  [1, 91, 17, 1585, 46, 380, 381, 13, 984],
#  [1,
#   129,
#   66,
#   206,
#   22,
#   7,
#   28,
#   200,
#   206,
#   134,
#   1,
#   1503,
#   16,
#   1,
#   948,
#   41,
#   21,
#   761,
#   631,
#   773,
#   1,
#   68,
#   1070],
#  [70,
#   134,
#   198,
#   361,
#   121,
#   1267,
#   3,
#   754,
#   37,
#   77,
#   56,
#   34,
#   25,
#   164,
#   1,
#   591,
#   143,
#   3,
#   44,
#   215,
#   1268,
#   195,
#   7],
#  [14,
#   16,
#   13,
#   7,
#   63,
#   5,
#   950,
#   76,
#   176,
#   3,
#   98,
#   12,
#   2,
#   311,
#   1737,
#   1,
#   117,
#   25,
#   1343,
#   4,
#   835,
#   113,
#   83,
#   272,
#   21,
#   14,
#   28,
#   936,
#   2,
#   6,
#   9,
#   33,
#   240,
#   230,
#   121,
#   28,
#   200,
#   298,
#   15,
#   1,
#   226,
#   5,
#   1675,
#   1851,
#   2,
#   4,
#   121,
#   346,
#   110,
#   7,
#   3,
#   312,
#   26,
#   1728,
#   1,
#   3,
#   6,
#   33,
#   268,
#   25,
#   61,
#   1,
#   11,
#   163,
#   354,
#   39,
#   1,
#   297,
#   4,
#   166,
#   12,
#   5,
#   885,
#   41,
#   8,
#   132,
#   46,
#   62,
#   7],
#  [133, 55, 172],
#  [1, 134, 392, 35, 75, 3, 6, 389],
#  [22,
#   436,
#   20,
#   5,
#   1098,
#   539,
#   1099,
#   1100,
#   1101,
#   3,
#   193,
#   6,
#   96,
#   40,
#   22,
#   278,
#   8,
#   297,
#   18,
#   3,
#   193,
#   6,
#   96,
#   79,
#   188,
#   141,
#   723,
#   1102,
#   2,
#   6,
#   33,
#   50,
#   47,
#   200,
#   298,
#   41,
#   22,
#   221],
#  [4, 84, 27, 25, 5, 179, 13, 177, 26, 9, 6, 266, 32, 1636, 25, 231],
#  [43,
#   1773,
#   143,
#   24,
#   36,
#   648,
#   191,
#   346,
#   854,
#   653,
#   43,
#   91,
#   1774,
#   10,
#   6,
#   1775,
#   653,
#   4,
#   1776,
#   67,
#   1777,
#   6,
#   1778,
#   628],
#  [1965, 4, 90, 65, 1057, 5, 635, 20, 4, 800, 76, 176, 599],
#  [1, 30, 569, 3, 47, 16, 26],
#  [8, 776, 104, 7, 3, 17, 1572, 12, 19, 24, 1, 91, 109, 19, 3, 62, 7],
#  [8, 504, 249, 3, 190, 7],
#  [802],
#  [1, 504, 313, 1, 11, 610, 13, 236],
#  [1, 67, 62, 19],
#  [84, 69, 257, 60, 197, 2, 232, 2, 510, 7],
#  [369, 38, 1386, 11, 35, 79, 20, 4, 1418, 316, 238, 4, 65, 90, 1417],
#  [4,
#   179,
#   84,
#   2,
#   1,
#   17,
#   2,
#   43,
#   398,
#   200,
#   131,
#   116,
#   10,
#   6,
#   360,
#   96,
#   42,
#   21,
#   239],
#  [294, 1, 504, 91, 66, 41, 406, 274, 44, 488],
#  [948, 41, 86, 29, 21, 82, 488, 1215],
#  [1,
#   91,
#   104,
#   339,
#   41,
#   1,
#   17,
#   3,
#   3,
#   44,
#   10,
#   5,
#   838,
#   63,
#   162,
#   63,
#   302,
#   68,
#   1,
#   17,
#   101,
#   449,
#   150,
#   59,
#   1846],
#  [1, 17, 94, 9, 6, 33, 15, 1, 17, 25, 366, 12, 10, 21, 1517, 395, 1188, 1189],
#  [1, 529, 12, 19, 10, 460, 1462, 13, 32, 240, 8, 505, 7, 343, 2, 7, 49, 325],
#  [1, 17, 25, 10, 772, 23, 1005, 10, 4, 113],
#  [6,
#   323,
#   1,
#   66,
#   49,
#   803,
#   595,
#   2,
#   22,
#   14,
#   203,
#   58,
#   652,
#   18,
#   813,
#   63,
#   22,
#   274,
#   44],
#  [65, 64, 2, 1, 45, 399, 10],
#  [43,
#   378,
#   144,
#   6,
#   96,
#   653,
#   43,
#   17,
#   101,
#   218,
#   2,
#   4,
#   166,
#   14,
#   95,
#   8,
#   1997,
#   339,
#   9,
#   4,
#   72,
#   4,
#   108,
#   600,
#   100,
#   1880,
#   49,
#   653,
#   18],
#  [115, 1730],
#  [15, 704, 1495, 7, 49, 4, 49, 6, 76, 9, 179, 33, 56, 228, 7, 164],
#  [1, 313, 247, 10, 12, 90, 50, 44, 124, 24, 16, 25, 28, 28, 187],
#  [1, 109, 3, 363, 978, 13, 4, 340, 76, 176, 15, 43, 385],
#  [1, 66, 414, 6],
#  [24, 22, 403, 75, 74, 3, 4, 2, 53, 42, 4, 392, 12, 18],
#  [1,
#   391,
#   21,
#   242,
#   37,
#   70,
#   11,
#   1215,
#   5,
#   3,
#   260,
#   33,
#   1410,
#   2,
#   53,
#   30,
#   59,
#   511,
#   3,
#   6,
#   15,
#   1,
#   504,
#   134,
#   1923,
#   49,
#   94,
#   260,
#   111,
#   49,
#   4,
#   65,
#   2,
#   15,
#   1158,
#   44,
#   206,
#   53,
#   333,
#   260,
#   12,
#   4,
#   59,
#   90],
#  [173, 25, 226, 5, 1820, 79, 31, 161],
#  [6, 82, 150, 79, 4, 204, 2, 53, 594, 15, 8, 149, 79, 2, 833, 3, 243, 7, 89],
#  [1, 17, 25, 99, 119, 79, 4, 84, 13, 32],
#  [827, 173, 438, 13, 4, 1683, 113],
#  [1, 470, 16, 164, 1370, 2, 1967, 6, 135, 13, 5, 76],
#  [4, 1156, 81, 188, 27, 5, 181, 9, 390, 458, 613, 2, 344, 602],
#  [8,
#   100,
#   935,
#   42,
#   7,
#   2,
#   85,
#   1213,
#   82,
#   56,
#   75,
#   3,
#   62,
#   7,
#   8,
#   159,
#   3,
#   897,
#   86,
#   2,
#   236,
#   370,
#   5,
#   39,
#   900],
#  [1, 249, 92, 49, 31, 105, 2, 158, 8, 69, 415, 8, 85, 6, 45, 11, 40, 9, 16],
#  [36,
#   199,
#   302,
#   7,
#   15,
#   143,
#   2,
#   1069,
#   1,
#   15,
#   142,
#   24,
#   131,
#   57,
#   1,
#   17,
#   25,
#   3,
#   33,
#   92],
#  [1, 413, 49, 4, 23, 737, 115, 76],
#  [173, 470, 6, 1956, 9, 331, 430, 37, 70, 271, 6, 64, 2, 169],
#  [1, 69, 234, 39, 8, 2, 106, 7, 15, 8, 134],
#  [963],
#  [16, 436, 7, 103, 835, 32, 3, 207, 44, 345, 3, 521, 4, 33],
#  [1,
#   11,
#   62,
#   481,
#   55,
#   364,
#   123,
#   76,
#   217,
#   2,
#   104,
#   215,
#   1667,
#   22,
#   50,
#   1135,
#   643,
#   41,
#   1,
#   125,
#   2,
#   22,
#   104,
#   34,
#   5,
#   1046,
#   363,
#   10,
#   6,
#   1546],
#  [4,
#   81,
#   85,
#   271,
#   517,
#   258,
#   1,
#   11,
#   42,
#   490,
#   8,
#   1764,
#   275,
#   79,
#   1765,
#   94,
#   1766,
#   1767,
#   29,
#   94,
#   126,
#   106,
#   15,
#   21,
#   96,
#   11,
#   13,
#   976,
#   609,
#   2,
#   275,
#   185,
#   1768,
#   6,
#   577,
#   8,
#   152,
#   4,
#   121,
#   656,
#   15,
#   349,
#   17,
#   94,
#   1769],
#  [22, 27, 34, 1407, 20, 178, 158, 12, 18, 54, 330, 20, 6, 360, 931],
#  [1,
#   109,
#   3,
#   144,
#   2,
#   267,
#   4,
#   599,
#   12,
#   7,
#   3,
#   31,
#   1328,
#   975,
#   203,
#   1,
#   17,
#   101,
#   3,
#   52,
#   28,
#   63,
#   1,
#   51,
#   58,
#   20,
#   6,
#   1401],
#  [4, 167, 2, 1, 82, 20, 5, 150, 59, 2, 380],
#  [1,
#   11,
#   313,
#   6,
#   24,
#   15,
#   1158,
#   267,
#   5,
#   318,
#   2,
#   1,
#   221,
#   66,
#   41,
#   224,
#   34,
#   141,
#   54,
#   2,
#   240,
#   1,
#   73,
#   46,
#   73,
#   347,
#   3,
#   521,
#   16,
#   63,
#   1,
#   137,
#   6],
#  [24, 1, 17, 5, 229, 55, 15],
#  [4,
#   264,
#   54,
#   1800,
#   80,
#   1801,
#   132,
#   3,
#   734,
#   79,
#   18,
#   65,
#   84,
#   11,
#   343,
#   5,
#   593,
#   13,
#   1816,
#   5,
#   30,
#   59],
#  [369,
#   94,
#   126,
#   297,
#   191,
#   3,
#   1644,
#   123,
#   96,
#   2,
#   6,
#   130,
#   8,
#   1645,
#   2,
#   31,
#   1646,
#   2,
#   211,
#   1647,
#   1648,
#   15,
#   154,
#   5,
#   187,
#   126,
#   4,
#   72,
#   356,
#   31,
#   338,
#   1649,
#   8,
#   466,
#   2,
#   57,
#   15,
#   22,
#   85,
#   349,
#   1650,
#   15,
#   338],
#  [4, 131, 1131, 9, 4, 166, 11, 80, 119, 23, 3, 4, 518],
#  [1, 50, 29, 3, 918, 238, 4, 64],
#  [1, 183, 1816, 172, 479, 246],
#  [1, 149, 932, 55, 12, 56],
#  [4, 102, 188, 27, 5, 1046, 495, 2, 27, 3, 821, 13, 612, 268, 19, 1516],
#  [1, 370, 35, 12, 4, 65, 282, 163, 580, 213, 71],
#  [4, 161, 69, 179, 371, 2, 399, 35, 2, 4],
#  [89,
#   919,
#   130,
#   215,
#   24,
#   43,
#   17,
#   5,
#   1008,
#   2,
#   1,
#   109,
#   3,
#   44,
#   3,
#   48,
#   1106,
#   1906,
#   37,
#   361,
#   2,
#   48,
#   15,
#   104,
#   41,
#   6,
#   589,
#   50,
#   762,
#   58,
#   339,
#   254,
#   16,
#   30,
#   1211,
#   7,
#   88,
#   479],
#  [274, 1, 233, 35, 12, 18],
#  [948, 21, 14, 162],
#  [1, 216, 10, 12, 19, 57, 365, 13, 174, 182, 78, 653, 1, 11, 28, 10, 202],
#  [21, 11, 57, 22, 34, 510, 19, 236, 20, 6, 883],
#  [41, 4, 518, 288, 289, 7, 312, 74, 10, 12, 18, 100, 1, 382, 17, 3, 363, 172],
#  [6, 140, 133, 55, 8, 235, 69, 179, 8, 232, 7],
#  [94, 169, 172, 82, 30, 853, 15, 70, 36, 17, 25, 293, 761, 936],
#  [4,
#   65,
#   167,
#   2,
#   167,
#   497,
#   26,
#   49,
#   7,
#   15,
#   8,
#   11,
#   23,
#   7,
#   268,
#   14,
#   206,
#   1,
#   399,
#   6,
#   45],
#  [30, 37, 180, 245, 240, 18, 72, 23, 222, 2, 119, 414, 140, 561],
#  [95, 19, 40, 18, 643, 1618, 2, 19],
#  [1, 488, 37, 16, 2, 11, 967, 26, 37, 75, 3, 1370, 13, 6, 135, 9, 337],
#  [4, 282, 14, 366, 12, 6, 33, 8, 49, 31, 65, 244, 13, 800, 32],
#  [53,
#   10,
#   680,
#   2,
#   304,
#   210,
#   3,
#   47,
#   20,
#   12,
#   4,
#   113,
#   24,
#   414,
#   140,
#   588,
#   141,
#   208,
#   50,
#   44,
#   1154],
#  [1, 347, 58, 3, 611, 3, 19, 24, 16, 642],
#  [1, 66, 21, 288, 115],
#  [24,
#   41,
#   5,
#   323,
#   324,
#   16,
#   2,
#   524,
#   99,
#   16,
#   58,
#   1058,
#   3,
#   199,
#   176,
#   56,
#   28,
#   40,
#   16,
#   692,
#   178,
#   63,
#   261,
#   665],
#  [1, 116, 12, 5, 675, 1139, 161, 54, 493, 179],
#  [1, 51, 252, 1863, 511, 3, 531, 12, 16, 2, 1, 88, 24, 137, 3, 17, 5],
#  [4, 23, 65, 987, 54, 1, 529, 12, 6, 115, 76],
#  [465,
#   171,
#   33,
#   4,
#   255,
#   27,
#   25,
#   1483,
#   2,
#   1,
#   117,
#   25,
#   210,
#   3,
#   327,
#   6,
#   10,
#   1024,
#   4,
#   244,
#   12,
#   18,
#   390,
#   458,
#   2,
#   4,
#   1328],
#  [173, 25, 250, 79, 4, 65, 13, 136, 5, 76, 2, 91, 66, 240, 3, 112, 13, 98],
#  [103, 32, 57, 5, 954],
#  [757, 891, 11],
#  [302, 162],
#  [74, 10, 1730, 1, 1418, 4, 102, 132, 4, 518],
#  [24, 1846, 8, 69, 290, 2, 58, 104, 38, 1263, 256, 8, 11, 74, 42, 6, 96],
#  [36, 95, 93, 4, 39, 36, 47, 415, 39, 36, 82, 332, 148],
#  [4, 361, 121, 362, 3, 44, 234, 42, 7, 10, 94, 130],
#  [394, 15, 1, 51, 329, 13, 484],
#  [39,
#   43,
#   156,
#   326,
#   35,
#   8,
#   85,
#   8,
#   569,
#   3,
#   392,
#   86,
#   3,
#   204,
#   20,
#   31,
#   390,
#   458,
#   139,
#   114,
#   8,
#   148,
#   68,
#   3,
#   7],
#  [1, 17, 101, 15, 8, 27, 93, 6, 1059, 153, 253, 18, 1172, 6, 111],
#  [1, 11, 13, 182, 32, 24, 21, 1, 313, 1, 175, 8, 60],
#  [49, 6, 8, 470, 1, 183, 8, 11, 1277, 18, 2, 18, 925, 6, 431],
#  [8, 62, 7],
#  [274,
#   1,
#   144,
#   28,
#   4,
#   90,
#   2,
#   1,
#   17,
#   25,
#   365,
#   13,
#   37,
#   177,
#   78,
#   43,
#   17,
#   25,
#   1011,
#   959,
#   153,
#   13,
#   37,
#   103,
#   32],
#  [1, 740, 2, 4, 282, 46, 65, 27, 62, 7, 5, 147, 223, 114, 21],
#  [4, 72, 30, 462, 7, 2, 805, 48, 136, 4, 1425],
#  [236, 158, 1, 125, 272, 375, 67, 611, 3, 15, 196, 158],
#  [452, 48],
#  [77, 274, 1, 52],
#  [21, 835, 395, 14, 5, 383, 593],
#  [101,
#   13,
#   7,
#   1,
#   73,
#   56,
#   137,
#   7,
#   3,
#   1254,
#   35,
#   13,
#   92,
#   5,
#   212,
#   241,
#   215,
#   28,
#   1053,
#   685,
#   375,
#   30,
#   789,
#   212,
#   241,
#   24,
#   1,
#   66,
#   1,
#   149,
#   971,
#   2,
#   1,
#   30,
#   789,
#   104,
#   30,
#   303,
#   329,
#   29,
#   4,
#   1179,
#   56,
#   110,
#   18,
#   1,
#   91,
#   12,
#   18,
#   46,
#   148,
#   29,
#   15,
#   12,
#   10,
#   7,
#   26,
#   9,
#   6,
#   96,
#   150,
#   294,
#   1,
#   567,
#   247,
#   439,
#   53,
#   271,
#   644,
#   62,
#   7,
#   5,
#   367,
#   9,
#   223,
#   24,
#   259,
#   29,
#   21,
#   240,
#   22,
#   30,
#   574,
#   5,
#   510,
#   20,
#   7,
#   40,
#   1,
#   11,
#   210,
#   3,
#   923,
#   4,
#   374,
#   2,
#   24,
#   1,
#   567,
#   29,
#   247,
#   439,
#   345,
#   28,
#   2,
#   22,
#   11,
#   341,
#   15,
#   2,
#   4,
#   211,
#   2,
#   5,
#   1,
#   112,
#   292,
#   43,
#   392,
#   35,
#   250,
#   74,
#   3,
#   7,
#   29,
#   146,
#   127,
#   256,
#   1,
#   73,
#   347,
#   3,
#   611,
#   83,
#   18,
#   2,
#   1,
#   73,
#   35,
#   5,
#   307,
#   3,
#   112,
#   2,
#   576,
#   289,
#   7,
#   30,
#   611,
#   3,
#   56,
#   2,
#   375,
#   144,
#   56,
#   317,
#   30,
#   289,
#   7,
#   289,
#   7,
#   110,
#   56,
#   206,
#   56,
#   101,
#   985,
#   774,
#   18,
#   7,
#   2,
#   18,
#   398,
#   10,
#   5,
#   212,
#   431,
#   2,
#   22,
#   221,
#   109,
#   3,
#   573,
#   10,
#   15,
#   431,
#   3,
#   112,
#   40,
#   18,
#   108,
#   221,
#   68,
#   109,
#   3,
#   363,
#   46,
#   842,
#   104,
#   18,
#   28,
#   156,
#   942,
#   1311,
#   240,
#   43,
#   30,
#   69,
#   774,
#   13,
#   10,
#   5,
#   213,
#   12,
#   5,
#   2,
#   53,
#   210,
#   3,
#   15,
#   3,
#   18,
#   904,
#   6,
#   131,
#   943,
#   1562,
#   477,
#   21,
#   130,
#   388,
#   6,
#   115,
#   56,
#   235,
#   76,
#   59,
#   42,
#   133,
#   566,
#   7,
#   35,
#   100,
#   138,
#   3,
#   222,
#   2,
#   120,
#   99,
#   7,
#   1,
#   152,
#   3,
#   1535,
#   1536,
#   87,
#   111,
#   13,
#   295,
#   32,
#   4,
#   244,
#   34,
#   25,
#   42,
#   25,
#   400,
#   1,
#   831,
#   1,
#   67,
#   236,
#   1,
#   11,
#   784,
#   67,
#   3,
#   62,
#   5,
#   323,
#   2,
#   1,
#   30,
#   289,
#   18,
#   52,
#   16,
#   67,
#   236,
#   335,
#   18,
#   22,
#   10,
#   5,
#   143,
#   190,
#   7,
#   2,
#   2,
#   34,
#   29,
#   921,
#   643,
#   1540,
#   2,
#   60,
#   9,
#   6,
#   55,
#   210,
#   3,
#   923,
#   5,
#   635,
#   49,
#   18,
#   2,
#   16,
#   275,
#   178,
#   2,
#   1,
#   30,
#   34,
#   345,
#   2,
#   28,
#   1,
#   399,
#   35,
#   788,
#   4,
#   374,
#   2,
#   22,
#   134,
#   21,
#   206,
#   1,
#   95,
#   34,
#   924,
#   69,
#   16,
#   26,
#   2,
#   100,
#   56,
#   256,
#   1,
#   399,
#   35,
#   227,
#   4,
#   244,
#   1,
#   152,
#   26,
#   172,
#   152,
#   925,
#   18,
#   2,
#   22,
#   1,
#   274,
#   104,
#   21,
#   237,
#   53,
#   1542,
#   271,
#   625,
#   283,
#   86,
#   3,
#   7,
#   2,
#   375,
#   1544,
#   7,
#   35,
#   2,
#   100,
#   303,
#   927,
#   7,
#   184,
#   927,
#   7,
#   184,
#   2,
#   173,
#   67,
#   104,
#   5,
#   118,
#   50,
#   52,
#   36,
#   85,
#   86,
#   3,
#   7,
#   15,
#   15,
#   4,
#   65,
#   54,
#   11,
#   20,
#   539,
#   1546,
#   1547,
#   2,
#   286,
#   13,
#   67,
#   236,
#   85,
#   3,
#   7,
#   58,
#   60,
#   55,
#   22,
#   928,
#   259,
#   56,
#   157,
#   504,
#   199,
#   3,
#   5,
#   118,
#   63,
#   5,
#   929,
#   46,
#   5,
#   666,
#   7,
#   10,
#   6,
#   10,
#   6,
#   10,
#   6,
#   880,
#   586,
#   130,
#   14,
#   15,
#   123,
#   1548,
#   56,
#   50,
#   104,
#   1549,
#   191,
#   3,
#   69,
#   3,
#   6,
#   239,
#   240,
#   22,
#   138,
#   1550,
#   23,
#   22,
#   50,
#   21,
#   60,
#   55,
#   1551,
#   20,
#   4,
#   620,
#   693,
#   150,
#   57,
#   22,
#   85,
#   22,
#   202,
#   7,
#   29,
#   1553,
#   68,
#   1554,
#   2,
#   100,
#   1555,
#   2,
#   152,
#   74,
#   56,
#   29,
#   10,
#   21,
#   1556,
#   328,
#   110,
#   7,
#   15,
#   22,
#   175,
#   930,
#   5,
#   988,
#   1557,
#   20,
#   13,
#   1558,
#   22,
#   175,
#   930,
#   370,
#   35,
#   5,
#   68,
#   370,
#   35,
#   7,
#   16,
#   26,
#   172,
#   12,
#   5,
#   165,
#   46,
#   146,
#   57,
#   15,
#   505,
#   242,
#   7,
#   24,
#   22,
#   85,
#   271,
#   332,
#   16,
#   40,
#   1,
#   221,
#   17,
#   6,
#   1559,
#   3,
#   931,
#   18,
#   52,
#   16,
#   16,
#   3,
#   7,
#   106,
#   7,
#   15,
#   56,
#   156,
#   68,
#   826,
#   7,
#   22,
#   504,
#   112,
#   74,
#   26,
#   12,
#   7,
#   2,
#   100,
#   932,
#   5,
#   200,
#   55,
#   22,
#   157,
#   30,
#   1561,
#   7,
#   22,
#   75,
#   3,
#   112,
#   74,
#   26,
#   7,
#   2,
#   86,
#   69,
#   298,
#   1,
#   274,
#   47,
#   479,
#   22,
#   109,
#   60,
#   239,
#   22,
#   347,
#   3,
#   645,
#   7,
#   29,
#   5,
#   1425,
#   1564,
#   268,
#   1,
#   278,
#   11,
#   1565,
#   28,
#   22,
#   50,
#   194,
#   5,
#   1566,
#   3,
#   347,
#   3,
#   834,
#   77,
#   101,
#   100,
#   22,
#   138,
#   335,
#   7,
#   173,
#   25,
#   755,
#   646,
#   39,
#   1,
#   133,
#   175,
#   18,
#   1,
#   646,
#   1567,
#   1504,
#   126,
#   341,
#   148,
#   1568,
#   86,
#   3,
#   922,
#   29,
#   260,
#   374,
#   3,
#   47,
#   18,
#   52,
#   86,
#   1,
#   97,
#   34,
#   3,
#   148,
#   11,
#   35,
#   1,
#   303,
#   3,
#   576,
#   628,
#   28,
#   1571,
#   56,
#   22,
#   69,
#   408,
#   34,
#   1572,
#   12,
#   18,
#   65,
#   273,
#   7,
#   15,
#   22,
#   134,
#   15,
#   3,
#   190,
#   6,
#   296,
#   20,
#   647,
#   2,
#   505,
#   326,
#   35,
#   7,
#   2,
#   1573,
#   10,
#   268,
#   53,
#   22,
#   11,
#   178,
#   332,
#   148,
#   94,
#   373,
#   152,
#   74,
#   15,
#   2,
#   279,
#   7,
#   49,
#   6,
#   389,
#   201,
#   6,
#   296,
#   101,
#   2,
#   16,
#   11,
#   1574,
#   296,
#   152,
#   26,
#   296,
#   43,
#   953,
#   34,
#   5,
#   1575,
#   13,
#   19,
#   13,
#   18,
#   1,
#   68,
#   170,
#   6,
#   296,
#   2,
#   39,
#   1,
#   69,
#   3,
#   6,
#   389,
#   36,
#   36,
#   109,
#   60,
#   89,
#   28,
#   1,
#   157,
#   6,
#   153,
#   2,
#   935,
#   42,
#   7,
#   2,
#   85,
#   52,
#   43,
#   137,
#   3,
#   17,
#   1576,
#   3,
#   308,
#   902,
#   46,
#   148,
#   15,
#   145,
#   35,
#   172,
#   29,
#   31,
#   10,
#   29,
#   741,
#   501,
#   22,
#   504,
#   134,
#   16,
#   2,
#   36,
#   66,
#   22,
#   221,
#   66,
#   36,
#   66,
#   77,
#   22,
#   221,
#   22,
#   134,
#   15,
#   20,
#   647,
#   2,
#   22,
#   181,
#   24,
#   56,
#   259,
#   10,
#   1579,
#   11,
#   48,
#   66,
#   1,
#   24,
#   1,
#   69,
#   3,
#   5,
#   239,
#   3,
#   22,
#   138,
#   335,
#   7,
#   69,
#   3,
#   2,
#   1,
#   50,
#   199,
#   37,
#   146,
#   212,
#   39,
#   21,
#   584,
#   328,
#   68,
#   220,
#   480,
#   178,
#   1,
#   388,
#   5,
#   213,
#   42,
#   18,
#   96,
#   89,
#   24,
#   22,
#   69,
#   48,
#   1762,
#   178,
#   40,
#   53,
#   28,
#   269,
#   3,
#   110,
#   7,
#   100,
#   104,
#   4,
#   189,
#   19,
#   63,
#   1,
#   157,
#   22,
#   7,
#   13,
#   15,
#   334,
#   101,
#   13,
#   7,
#   1,
#   199,
#   685,
#   56,
#   137,
#   7,
#   3,
#   1254,
#   35,
#   92,
#   5,
#   212,
#   241,
#   215,
#   28,
#   1053,
#   685,
#   375,
#   30,
#   789,
#   241,
#   24,
#   1,
#   66,
#   1,
#   149,
#   685,
#   2,
#   1,
#   30,
#   789,
#   104,
#   30,
#   303,
#   329,
#   4,
#   1179,
#   56,
#   110,
#   18,
#   1,
#   91,
#   12,
#   18,
#   46,
#   148,
#   29,
#   15,
#   916,
#   103,
#   127,
#   7,
#   26,
#   9,
#   6,
#   96,
#   150,
#   294,
#   1,
#   567,
#   247,
#   439,
#   55,
#   271,
#   644,
#   62,
#   7,
#   5,
#   367,
#   223,
#   24,
#   259,
#   29,
#   21,
#   240,
#   22,
#   30,
#   109,
#   3,
#   1291,
#   16,
#   20,
#   7,
#   40,
#   1,
#   11,
#   210,
#   923,
#   4,
#   374,
#   2,
#   24,
#   1,
#   567,
#   29,
#   247,
#   439,
#   345,
#   28,
#   2,
#   22,
#   11,
#   341,
#   15,
#   2,
#   4,
#   211,
#   10,
#   6,
#   1,
#   ...],
#  [70,
#   134,
#   198,
#   361,
#   121,
#   1267,
#   3,
#   754,
#   37,
#   77,
#   56,
#   34,
#   25,
#   164,
#   1,
#   591,
#   143,
#   3,
#   44,
#   215,
#   1268,
#   195,
#   7],
#  [1, 17, 644, 935, 83, 13, 143, 28, 394, 1, 129, 137, 208],
#  [150, 89, 156, 153, 225, 845, 941, 609],
#  [28, 1, 117, 25, 12, 4, 282, 13, 5, 76, 59, 2, 530, 6, 76, 8, 1406, 179],
#  [1,
#   17,
#   67,
#   25,
#   179,
#   46,
#   348,
#   364,
#   450,
#   12,
#   224,
#   454,
#   2,
#   4,
#   277,
#   590,
#   7,
#   4,
#   557,
#   28,
#   15,
#   39,
#   4,
#   166,
#   4,
#   1,
#   91,
#   233,
#   2,
#   303,
#   1001,
#   74],
#  [1, 51, 5, 988, 76, 176, 666, 54, 27, 25, 99, 18, 1683, 113],
#  [1841, 45, 1, 17, 15, 202, 149, 44, 1797, 185, 49, 7, 42, 141, 55],
#  [8, 62, 7, 114, 21, 24, 21, 55, 14, 1456, 8, 68, 249, 3, 93, 7],
#  [8, 138, 7, 335, 7, 10, 4, 2, 211],
#  [4, 65, 11, 119, 2, 336, 23],
#  [1, 175, 4, 65, 282, 30, 136, 177, 32, 71],
#  [69, 10, 5, 541, 12, 19, 555, 2, 8, 510, 7, 57, 5, 147, 407, 2, 335],
#  [4, 1517, 23, 45, 11, 1518, 251, 1519],
#  [4, 23, 65, 827, 1, 828, 26, 263, 71, 27, 5, 72, 54, 97, 1304, 19],
#  [1, 411, 39, 6, 617, 683, 31, 172, 299, 32, 71],
#  [7, 1359, 2, 4, 166, 1229, 17, 25, 293, 217],
#  [89, 11, 5, 9, 1018, 33, 10, 6, 45, 268, 3, 602, 6],
#  [1, 30, 109, 314, 3, 44, 685],
#  [24, 100, 8, 1472, 1, 313, 335, 7, 136, 2, 136, 10, 4, 1425],
#  [53,
#   765,
#   18,
#   75,
#   51,
#   1,
#   6,
#   23,
#   60,
#   1,
#   106,
#   19,
#   42,
#   55,
#   131,
#   19,
#   2,
#   31,
#   108,
#   194,
#   6,
#   53,
#   67,
#   506,
#   3,
#   44,
#   10,
#   6,
#   603,
#   631],
#  [6,
#   1260,
#   152,
#   139,
#   16,
#   11,
#   136,
#   6,
#   133,
#   1,
#   17,
#   9,
#   19,
#   14,
#   30,
#   218,
#   26,
#   9,
#   5,
#   2,
#   16,
#   10,
#   6],
#  [8, 11, 2, 3, 821, 2, 388, 266, 32, 89],
#  [1, 91, 66, 240, 454, 3, 406, 1754],
#  [1, 106, 19, 173, 25, 250, 525, 99, 13, 32, 10, 4, 255],
#  [1,
#   109,
#   3,
#   267,
#   94,
#   238,
#   19,
#   24,
#   4,
#   518,
#   14,
#   426,
#   39,
#   1,
#   249,
#   3,
#   611,
#   3,
#   18,
#   37,
#   16,
#   2,
#   341,
#   16,
#   11,
#   7,
#   453,
#   143,
#   2,
#   15,
#   1,
#   69,
#   166,
#   3,
#   44,
#   23],
#  [1,
#   51,
#   5,
#   988,
#   76,
#   176,
#   237,
#   2,
#   4,
#   115,
#   45,
#   11,
#   10,
#   649,
#   240,
#   1,
#   125,
#   6,
#   500,
#   12,
#   5,
#   731,
#   76,
#   176,
#   196,
#   2,
#   1,
#   893,
#   5,
#   954,
#   45],
#  [1,
#   66,
#   89,
#   1522,
#   14,
#   3,
#   931,
#   19,
#   24,
#   4,
#   682,
#   14,
#   107,
#   797,
#   3,
#   19,
#   2,
#   6,
#   657,
#   15,
#   1,
#   93,
#   19,
#   79,
#   227]]

# %%
tokenizer.word_docs
# Out:
# defaultdict(int,
#             {'nieces': 1,
#              'my': 311,
#              'ex': 33,
#              'the': 225,
#              'of': 174,
#              'person': 17,
#              "isn't": 5,
#              'than': 8,
#              'father': 20,
#              'rather': 2,
#              'sisters': 2,
#              'question': 3,
#              'and': 344,
#              'in': 161,
#              'if': 47,
#              'leaving': 9,
#              'experienced': 4,
#              'physically': 19,
#              'you': 25,
#              'after': 39,
#              'a': 240,
#              'this': 85,
#              'any': 15,
#              'idk': 8,
#              'abusive': 86,
#              'relationship': 46,
#              '8': 7,
#              'been': 73,
#              'its': 4,
#              'marriage': 8,
#              'out': 67,
#              'i': 416,
#              'days': 18,
#              'since': 36,
#              'got': 31,
#              'later': 8,
#              '2': 21,
#              'he': 175,
#              'it': 90,
#              'again': 14,
#              'months': 27,
#              'did': 14,
#              'even': 20,
#              'how': 31,
#              'to': 286,
#              'know': 31,
#              'into': 26,
#              'words': 3,
#              "don't": 22,
#              'put': 9,
#              'abuse': 62,
#              'happened': 15,
#              'bf': 7,
#              'me': 196,
#              'for': 119,
#              'away': 12,
#              'ago': 35,
#              'passed': 3,
#              'with': 116,
#              'who': 43,
#              'month': 10,
#              'keep': 10,
#              'blaming': 2,
#              'right': 14,
#              'myself': 22,
#              'now': 37,
#              'that': 95,
#              'helping': 1,
#              'all': 44,
#              'by': 29,
#              'hard': 9,
#              'is': 108,
#              'but': 77,
#              'at': 44,
#              'family': 21,
#              'get': 44,
#              'things': 20,
#              'promise': 1,
#              "here's": 1,
#              'make': 9,
#              'list': 1,
#              'drunk': 8,
#              'towards': 11,
#              'was': 141,
#              'knew': 7,
#              'time': 35,
#              'angry': 4,
#              'an': 52,
#              'anything': 18,
#              'never': 30,
#              'old': 13,
#              'boyfriend': 24,
#              'female': 2,
#              '17': 4,
#              'year': 28,
#              '19': 5,
#              '20': 5,
#              'when': 51,
#              'given': 2,
#              'told': 20,
#              'their': 8,
#              '28': 1,
#              'call': 7,
#              'card': 2,
#              'didn': 15,
#              'them': 13,
#              'from': 38,
#              'hear': 4,
#              'dec': 1,
#              'had': 52,
#              'voicemail': 1,
#              'leave': 15,
#              'him': 84,
#              'man': 11,
#              'his': 54,
#              'corner': 2,
#              'lift': 1,
#              'about': 55,
#              'literally': 4,
#              'backed': 1,
#              'repeatedly': 2,
#              'snapped': 1,
#              'until': 12,
#              'hit': 36,
#              'fist': 1,
#              'pretending': 1,
#              'years': 61,
#              '30m': 2,
#              'husband': 27,
#              'emotionally': 19,
#              '5': 13,
#              'himself': 7,
#              'repeated': 2,
#              'what': 29,
#              'elaborate': 1,
#              'just': 53,
#              'meant': 5,
#              'asked': 5,
#              'before': 20,
#              'older': 4,
#              'attacks': 2,
#              'smoke': 1,
#              'calm': 3,
#              'sister': 26,
#              'quite': 1,
#              'loud': 2,
#              'crying': 6,
#              'ignorant': 1,
#              'voice': 2,
#              'said': 22,
#              'brother': 14,
#              'her': 66,
#              'going': 31,
#              'mainly': 1,
#              'smoking': 1,
#              'quit': 1,
#              'on': 78,
#              'couldn': 3,
#              'mum': 2,
#              'while': 6,
#              'distress': 1,
#              'used': 14,
#              'younger': 2,
#              'help': 20,
#              'do': 36,
#              'would': 35,
#              'calling': 3,
#              'scared': 14,
#              'weed': 1,
#              'have': 88,
#              'causing': 1,
#              'panic': 7,
#              'because': 50,
#              'suppose': 2,
#              'partner': 6,
#              'seriously': 4,
#              'don': 17,
#              'understand': 4,
#              'phone': 5,
#              'night': 11,
#              'give': 5,
#              'wouldn': 2,
#              'last': 19,
#              'parents': 19,
#              'title': 2,
#              'says': 7,
#              '26': 3,
#              'married': 9,
#              'choked': 8,
#              'weekend': 2,
#              'story': 6,
#              'short': 1,
#              'long': 14,
#              'really': 27,
#              'so': 64,
#              'can': 32,
#              'duplex': 1,
#              'live': 20,
#              'closely': 1,
#              'same': 5,
#              'type': 7,
#              'therapy': 2,
#              'intensive': 1,
#              'lay': 2,
#              'break': 9,
#              'or': 41,
#              'finger': 1,
#              'heart': 2,
#              'hurt': 21,
#              'some': 20,
#              'seem': 5,
#              'way': 18,
#              'mad': 9,
#              'abusers': 5,
#              'be': 44,
#              "mother's": 3,
#              'nothing': 6,
#              'police': 8,
#              'opened': 2,
#              'ever': 9,
#              'filed': 6,
#              'report': 3,
#              'name': 2,
#              'cards': 1,
#              'not': 36,
#              'yeah': 1,
#              'wedding': 1,
#              '2016': 1,
#              'like': 53,
#              'your': 11,
#              'seen': 2,
#              'okay': 2,
#              'she': 47,
#              'ou': 1,
#              'anally': 1,
#              'part': 4,
#              'raped': 2,
#              'regularly': 3,
#              'being': 28,
#              'pulled': 1,
#              'only': 18,
#              'around': 13,
#              'hair': 3,
#              'as': 28,
#              'sexual': 8,
#              'pushing': 2,
#              'struggle': 2,
#              'domestic': 26,
#              'otherside': 2,
#              'has': 72,
#              'still': 21,
#              'someone': 17,
#              'through': 14,
#              'focusing': 2,
#              'forward': 6,
#              'come': 16,
#              'comes': 2,
#              'woman': 6,
#              'gets': 3,
#              'abused': 22,
#              'acceptable': 1,
#              'off': 12,
#              'victim': 8,
#              'say': 11,
#              'does': 6,
#              'week': 14,
#              'birthday': 2,
#              'consider': 2,
#              'dad': 13,
#              'grew': 7,
#              'up': 51,
#              'kid': 1,
#              'sexually': 3,
#              'violent': 13,
#              'friend': 14,
#              '25f': 2,
#              'late20sm': 1,
#              '72': 1,
#              'mom': 21,
#              'everything': 10,
#              'steals': 1,
#              'much': 11,
#              'preety': 2,
#              'head': 7,
#              'jaw': 1,
#              'mother': 32,
#              'opportunities': 1,
#              'exhausted': 1,
#              'successful': 1,
#              'professional': 1,
#              'lost': 10,
#              'yes': 1,
#              'gaslighting': 1,
#              'working': 6,
#              'love': 11,
#              'am': 39,
#              'once': 7,
#              'bombing': 2,
#              'girl': 9,
#              'walked': 4,
#              'bedroom': 2,
#              'another': 4,
#              'panicking': 1,
#              'amd': 1,
#              'they': 48,
#              'two': 16,
#              'more': 10,
#              'dumb': 4,
#              'fucking': 7,
#              'won': 7,
#              'let': 7,
#              'stay': 5,
#              'friends': 13,
#              'there': 22,
#              'punching': 2,
#              'holes': 1,
#              'then': 17,
#              'wall': 3,
#              'abuser': 36,
#              'arrested': 7,
#              'devastated': 1,
#              'trafficker': 1,
#              'order': 17,
#              'although': 2,
#              'restraining': 7,
#              'granted': 1,
#              'developed': 1,
#              'during': 5,
#              'aggressive': 2,
#              'hemorrhoids': 1,
#              'currently': 11,
#              'home': 7,
#              'work': 10,
#              'company': 1,
#              'amazing': 2,
#              'want': 20,
#              'back': 27,
#              'power': 1,
#              '2014': 2,
#              'bad': 12,
#              'feel': 25,
#              'together': 9,
#              'living': 7,
#              'recently': 14,
#              'past': 12,
#              'basically': 12,
#              'we': 46,
#              'moved': 10,
#              'dealt': 1,
#              'e': 20,
#              'wont': 2,
#              'hello': 3,
#              'comments': 4,
#              'nr6wf8': 2,
#              'r': 4,
#              'com': 4,
#              'domesticviolence': 4,
#              'rentals': 1,
#              'almost': 10,
#              'lived': 3,
#              'lot': 13,
#              'gues': 1,
#              'room': 4,
#              'dating': 5,
#              '4': 13,
#              'struggling': 5,
#              'focus': 2,
#              'points': 1,
#              'beat': 17,
#              'funny': 2,
#              'helpless': 2,
#              'shared': 1,
#              'shit': 8,
#              'photo': 1,
#              'prior': 1,
#              'few': 16,
#              'pass': 1,
#              'well': 7,
#              'half': 3,
#              'couple': 5,
#              'weeks': 8,
#              'hasn': 1,
#              'tired': 4,
#              'why': 11,
#              'hearing': 2,
#              'defend': 1,
#              'sit': 1,
#              'tell': 18,
#              'state': 2,
#              'people': 13,
#              'freaking': 2,
#              'learned': 5,
#              'narcissistic': 2,
#              'terms': 3,
#              'finally': 11,
#              '6': 7,
#              'ishandle': 1,
#              'technically': 1,
#              'also': 23,
#              'baby': 3,
#              'sold': 1,
#              'animal': 1,
#              'shelter': 3,
#              'money': 10,
#              'doggie': 1,
#              'kind': 8,
#              'god': 3,
#              'drinking': 3,
#              'every': 10,
#              'pain': 4,
#              'stop': 4,
#              'prayed': 2,
#              'both': 4,
#              'realized': 2,
#              'kill': 11,
#              '11': 2,
#              'threatened': 7,
#              'yesterday': 5,
#              'broke': 4,
#              'girlfriend': 8,
#              'came': 10,
#              'drunken': 3,
#              'occasion': 2,
#              'sharing': 3,
#              'other': 15,
#              'one': 34,
#              'publicly': 2,
#              'soo': 2,
#              "he's": 12,
#              'signed': 2,
#              'nice': 3,
#              'breaking': 6,
#              'against': 9,
#              'limbo': 2,
#              'cyberstalking': 2,
#              'trial': 2,
#              'awaiting': 2,
#              'expenses': 1,
#              'piling': 1,
#              'needs': 3,
#              'today': 5,
#              'debt': 1,
#              "didn't": 8,
#              'necessary': 1,
#              'house': 17,
#              'worse': 7,
#              '13': 3,
#              'chapter': 1,
#              'took': 4,
#              'bankruptcy': 1,
#              'coerced': 1,
#              'means': 2,
#              'completely': 3,
#              'escalated': 4,
#              'wanted': 14,
#              'where': 9,
#              'either': 5,
#              'fight': 3,
#              'point': 7,
#              'known': 4,
#              'experiences': 1,
#              'awful': 2,
#              'stalker': 1,
#              'bit': 9,
#              'dated': 2,
#              'our': 18,
#              'close': 3,
#              'many': 7,
#              'over': 17,
#              'guys': 5,
#              'talking': 9,
#              'legit': 1,
#              'hands': 2,
#              'randomly': 1,
#              'throat': 1,
#              'gonna': 6,
#              'teeth': 1,
#              'stuff': 4,
#              'statistics': 1,
#              'find': 6,
#              'super': 2,
#              'oke': 1,
#              'grabbing': 3,
#              'thing': 6,
#              'scientific': 1,
#              'always': 21,
#              'fast': 4,
#              'aunt': 3,
#              'skip': 1,
#              'details': 4,
#              "i'll": 5,
#              'domestically': 1,
#              'violence': 21,
#              'idea': 4,
#              'happens': 4,
#              'looking': 6,
#              "i'm": 40,
#              'drink': 3,
#              'bunch': 3,
#              'walls': 2,
#              'ground': 1,
#              'pushed': 5,
#              'threw': 3,
#              'lives': 6,
#              'control': 4,
#              'world': 1,
#              'verbally': 10,
#              "can't": 4,
#              'meaningful': 1,
#              'afford': 1,
#              'problem': 1,
#              'emotional': 8,
#              'horrible': 7,
#              'physical': 14,
#              'reading': 6,
#              'three': 4,
#              'esteem': 1,
#              'realizations': 1,
#              'self': 2,
#              'talked': 3,
#              'impact': 1,
#              'us': 9,
#              'big': 4,
#              'stays': 1,
#              'surprised': 3,
#              '29': 2,
#              'mongolia': 1,
#              'anyways': 3,
#              'piece': 1,
#              'day': 15,
#              'ride': 1,
#              'minute': 1,
#              'blue': 1,
#              'coaster': 1,
#              "it's": 6,
#              'hate': 4,
#              'good': 17,
#              'bastard': 1,
#              'here': 12,
#              'torn': 1,
#              'roller': 1,
#              'real': 1,
#              'need': 17,
#              'start': 7,
#              'doing': 5,
#              'deactivate': 1,
#              'extremely': 6,
#              'proceeded': 1,
#              'accounts': 4,
#              'forced': 4,
#              'ten': 2,
#              'stayed': 4,
#              'heard': 3,
#              'verbatim': 1,
#              'threaten': 1,
#              'apartment': 5,
#              'doesn': 3,
#              'job': 4,
#              'separated': 3,
#              'fights': 4,
#              'bail': 1,
#              'threats': 2,
#              'sending': 2,
#              'hacked': 1,
#              'media': 5,
#              'death': 2,
#              'social': 5,
#              "i've": 14,
#              'done': 6,
#              'im': 7,
#              'f21': 2,
#              'autistic': 1,
#              '3': 14,
#              'extended': 1,
#              'household': 2,
#              'uncle': 2,
#              'daughters': 2,
#              'left': 19,
#              '7': 8,
#              'l': 5,
#              'example': 2,
#              '23': 2,
#              'times': 10,
#              'tonight': 3,
#              'go': 21,
#              'anymore': 7,
#              'livehere': 1,
#              'nowjere': 1,
#              'cause': 3,
#              'oh': 2,
#              'hurting': 3,
#              'suspected': 1,
#              'lied': 1,
#              'bruised': 4,
#              'beaten': 2,
#              'hi': 4,
#              'reddit': 3,
#              'controls': 1,
#              'finances': 3,
#              "household's": 1,
#              'aspects': 1,
#              'aunts': 1,
#              'hitting': 5,
#              'were': 15,
#              'started': 14,
#              'exploded': 1,
#              'arguing': 3,
#              'abusing': 4,
#              'killing': 2,
#              'else': 4,
#              'severe': 3,
#              'anyone': 10,
#              'trigger': 5,
#              'cptsd': 1,
#              'first': 17,
#              'mentally': 6,
#              'yacht': 3,
#              'inviting': 1,
#              'party': 3,
#              'flash': 1,
#              '18': 4,
#              'something': 14,
#              'bond': 1,
#              'upfront': 1,
#              'renting': 2,
#              'rent': 3,
#              'till': 4,
#              'think': 13,
#              'appreciate': 1,
#              'greatly': 1,
#              'advice': 11,
#              "i'd": 3,
#              '23f': 1,
#              '24m': 1,
#              'young': 7,
#              'christmas': 2,
#              'share': 5,
#              'sibling': 3,
#              'may': 1,
#              'suspect': 2,
#              'take': 8,
#              'cannot': 2,
#              'neighbors': 2,
#              'building': 3,
#              '36m': 1,
#              'parental': 1,
#              'children': 11,
#              'member': 2,
#              'due': 5,
#              'termination': 1,
#              'rights': 1,
#              'adopting': 1,
#              'are': 27,
#              'place': 7,
#              'wrong': 4,
#              'gang': 1,
#              'hang': 4,
#              'members': 2,
#              'strangled': 2,
#              'hung': 1,
#              'alot': 2,
#              'mental': 5,
#              'valentines': 1,
#              'which': 8,
#              'facility': 1,
#              'hospital': 4,
#              'spent': 5,
#              "wasn't": 3,
#              'health': 4,
#              'true': 1,
#              'doctors': 2,
#              'down': 11,
#              'total': 3,
#              'learning': 2,
#              'age': 4,
#              'picked': 1,
#              'noise': 2,
#              'downstairs': 1,
#              'ran': 2,
#              'spun': 1,
#              'see': 9,
#              'saw': 5,
#              'second': 2,
#              'memory': 3,
#              'witnessing': 1,
#              'child': 7,
#              'reliasing': 1,
#              'end': 5,
#              'needed': 3,
#              'strength': 3,
#              'conclusion': 1,
#              'poly': 1,
#              'cackling': 1,
#              'wife': 8,
#              'serious': 1,
#              'turned': 7,
#              'situation': 8,
#              'stalking': 2,
#              'incident': 3,
#              'kids': 3,
#              'attacked': 4,
#              'protection': 6,
#              'mums': 2,
#              "hasn't": 1,
#              'though': 9,
#              'probably': 2,
#              'isn': 2,
#              'sure': 8,
#              'too': 10,
#              'others': 3,
#              'counts': 1,
#              'ask': 2,
#              'opinion': 1,
#              'compared': 1,
#              'dramatic': 1,
#              'mate': 2,
#              'assaulted': 4,
#              'sleep': 2,
#              'covid': 4,
#              'decided': 7,
#              'w': 1,
#              'quarantine': 1,
#              'fairly': 1,
#              'new': 7,
#              'tw': 4,
#              'read': 2,
#              'posts': 1,
#              'slapped': 3,
#              'sub': 1,
#              'look': 3,
#              'https': 1,
#              'www': 1,
#              'cook': 1,
#              'amp': 15,
#              'gave': 3,
#              'recharged': 1,
#              'apply': 2,
#              'plate': 1,
#              'disconnected': 1,
#              'guy': 16,
#              'information': 1,
#              'service': 1,
#              'track': 1,
#              'below': 1,
#              'location': 3,
#              'pressure': 1,
#              'could': 14,
#              'number': 3,
#              'vehicle': 3,
#              'authorities': 3,
#              'sitting': 2,
#              'fell': 4,
#              'straight': 2,
#              'couch': 1,
#              'shoved': 2,
#              'floor': 5,
#              'rose': 1,
#              'quick': 1,
#              'leg': 2,
#              'concussion': 1,
#              'psychology': 1,
#              'united': 2,
#              'degree': 2,
#              'masters': 1,
#              'care': 6,
#              'certified': 1,
#              'fix': 2,
#              '2013': 1,
#              'actively': 1,
#              'pc': 1,
#              'please': 5,
#              '9': 3,
#              'maybe': 6,
#              'term': 1,
#              'several': 2,
#              'drop': 1,
#              'deff': 1,
#              'makes': 1,
#              'yet': 3,
#              'sense': 2,
#              'business': 1,
#              'saved': 2,
#              'no': 22,
#              'hat': 1,
#              'move': 6,
#              'felt': 4,
#              'stuck': 2,
#              "doesn't": 2,
#              'often': 1,
#              '4am': 1,
#              'woke': 2,
#              'screaming': 1,
#              'bonkers': 1,
#              '2007': 1,
#              'made': 4,
#              'flipped': 1,
#              'soon': 3,
#              'lockdowns': 1,
#              'moving': 8,
#              'cut': 3,
#              'ties': 1,
#              'possibly': 1,
#              'hopes': 1,
#              'receiving': 1,
#              'snuck': 1,
#              'bathroom': 1,
#              'morning': 4,
#              '12': 2,
#              'm': 2,
#              'guess': 2,
#              '60': 1,
#              'current': 3,
#              '64': 1,
#              '30': 3,
#              'slapping': 2,
#              'destroying': 1,
#              'belongings': 1,
#              'fwb': 1,
#              'apologize': 1,
#              'post': 5,
#              'messages': 1,
#              'instagram': 2,
#              'advance': 1,
#              'agreed': 1,
#              'exchanged': 1,
#              'met': 11,
#              'show': 5,
#              'born': 2,
#              'raised': 2,
#              'argentina': 1,
#              'breath': 2,
#              'trying': 10,
#              'catch': 1,
#              'regain': 1,
#              'reaching': 3,
#              'possible': 3,
#              'vent': 2,
#              'life': 20,
#              'avoid': 1,
#              'contact': 12,
#              'usually': 1,
#              'harm': 1,
#              'psychologically': 2,
#              'herself': 1,
#              'suffered': 1,
#              'twice': 4,
#              'violently': 1,
#              'didnt': 1,
#              "she's": 7,
#              'cracks': 1,
#              'pack': 2,
#              '1': 6,
#              'getaway': 1,
#              'front': 4,
#              'choke': 1,
#              'barely': 2,
#              'fake': 1,
#              'believe': 3,
#              'gotta': 1,
#              'thought': 7,
#              'stand': 1,
#              'guilty': 1,
#              'sometimes': 2,
#              'very': 16,
#              'babe': 1,
#              'next': 9,
#              'terrified': 2,
#              'jail': 4,
#              'difficult': 3,
#              'briefly': 2,
#              'judge': 3,
#              "wouldn't": 1,
#              'grant': 2,
#              'typically': 1,
#              'pleas': 1,
#              'medical': 2,
#              'donation': 1,
#              'visit': 1,
#              'bill': 1,
#              'marks': 1,
#              'hour': 1,
#              'aware': 2,
#              'insults': 5,
#              'coparent': 1,
#              'helped': 3,
#              'window': 1,
#              '911': 1,
#              'empathetic': 1,
#              'react': 1,
#              'expected': 3,
#              'open': 2,
#              'rant': 2,
#              'isbmore': 1,
#              'suggestions': 2,
#              'thinking': 8,
#              'might': 3,
#              'pretty': 5,
#              'cat': 4,
#              'worried': 4,
#              'fam': 2,
#              'minutes': 1,
#              'mailboxes': 1,
#              'standing': 1,
#              'saying': 6,
#              '15': 2,
#              'near': 1,
#              'traumatized': 2,
#              'brutal': 1,
#              'warning': 3,
#              'nonstop': 1,
#              'explicit': 1,
#              'tried': 9,
#              'beating': 5,
#              'strangling': 1,
#              'ended': 4,
#              'fingering': 1,
#              'background': 2,
#              'shambles': 1,
#              'afraid': 3,
#              'will': 15,
#              'knows': 6,
#              'feeling': 4,
#              'adhd': 2,
#              'bipolar': 2,
#              'disorder': 3,
#              'blood': 2,
#              'better': 4,
#              'loved': 3,
#              'insulted': 2,
#              'definite': 2,
#              'triggers': 2,
#              'general': 3,
#              'association': 2,
#              'routine': 3,
#              'change': 3,
#              'bereavement': 2,
#              'son': 3,
#              'turning': 2,
#              '14': 2,
#              'less': 3,
#              'recovery': 1,
#              'medication': 2,
#              'sees': 1,
#              'doctor': 1,
#              'therapist': 1,
#              'without': 6,
#              'problematic': 1,
#              'telling': 8,
#              'huge': 3,
#              'downward': 1,
#              'spiral': 1,
#              'denied': 2,
#              'solve': 1,
#              'depend': 2,
#              'major': 1,
#              'issues': 3,
#              'adult': 2,
#              'own': 4,
#              'bowls': 2,
#              'ordered': 1,
#              'finished': 2,
#              'punch': 1,
#              '240': 1,
#              'grossly': 1,
#              'pet': 1,
#              'rabbit': 1,
#              'helps': 1,
#              'tl': 2,
#              'dr': 2,
#              'agent': 1,
#              'parole': 1,
#              'getting': 9,
#              'contacted': 2,
#              'prison': 2,
#              'halloween': 1,
#              'assigned': 1,
#              'matching': 1,
#              'tattoos': 1,
#              'trap': 1,
#              'engaged': 2,
#              'kindergarten': 2,
#              'hated': 2,
#              'active': 1,
#              'create': 1,
#              'whom': 2,
#              'kicked': 2,
#              'enables': 1,
#              'fathers': 2,
#              'plan': 3,
#              'driving': 1,
#              '8hrs': 1,
#              'taken': 4,
#              'via': 1,
#              'confronted': 1,
#              'anger': 6,
#              'important': 1,
#              'tag': 1,
#              'multiple': 4,
#              'should': 8,
#              'steps': 2,
#              ...})

# %%
V= len(tokenizer.word_docs) # NO OF UNIQUE TOKENS
V
# Out:
# 2122

# %%
#Pad TRAIN DATA sequences with max length T

# %%
data_train = pad_sequences(sequences_train)

# %%
data_train
# Out:
# array([[   0,    0,    0, ...,    9,    4, 1023],
#        [   0,    0,    0, ...,  119,   23,   45],
#        [   0,    0,    0, ...,    4,   23,  255],
#        ...,
#        [   0,    0,    0, ...,   79,  105,  750],
#        [   0,    0,    0, ...,  213,  176,  620],
#        [   0,    0,    0, ...,  448,   10,    3]], dtype=int32)

# %%
data_train.shape
# Out:
# (800, 631)

# %%
T= data_train.shape[1]

# %%
T
# Out:
# 631

# %%
#Pad TEST DATA sequences with max length T

# %%
data_test = pad_sequences(sequences_test, maxlen=T)

# %%
data_test
# Out:
# array([[  0,   0,   0, ..., 514, 185,  10],
#        [  0,   0,   0, ..., 296,   2, 144],
#        [  0,   0,   0, ...,  43, 156, 560],
#        ...,
#        [  0,   0,   0, ...,   3,  44,  23],
#        [  0,   0,   0, ...,   5, 954,  45],
#        [  0,   0,   0, ...,  19,  79, 227]], dtype=int32)

# %%
data_train.shape
# Out:
# (800, 631)

# %%
data_test.shape
# Out:
# (200, 631)

# %%
data_train.shape[1]
# Out:
# 631

# %%
V= len(tokenizer.word_docs)
T = data_train.shape[1] #features

# %%
 #TF SHAPES
#   2000(word_embeddings) x D(just choose dimensions)x  T 162(features)

# %%
# Create the model

# We get to choose embedding dimensionality
D = 20

# Hidden state dimensionality
M = 15

# Note: we actually want to the size of the embedding to (V + 1) x D,
# because the first index starts from 1 and not 0.
# Thus, if the final index of the embedding matrix is V,
# then it actually must have size V + 1.

i = Input(shape=(T,))
x = Embedding(V + 1, D)(i) #return word vectors 
x = LSTM(M, return_sequences=True)(x) 
x = GlobalMaxPooling1D()(x)  #long term dependancies
x = Dense(1, activation='sigmoid')(x) #binary

model = Model(i, x)
model.summary()
# Out:
# Model: "model_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_24 (InputLayer)       [(None, 631)]             0
#
#  embedding_24 (Embedding)    (None, 631, 20)           42460
#
#  lstm_21 (LSTM)              (None, 631, 15)           2160
#
#  global_max_pooling1d_21 (Gl  (None, 15)               0
#  obalMaxPooling1D)
#
#  dense_21 (Dense)            (None, 1)                 16
#
# =================================================================
# Total params: 44,636
# Trainable params: 44,636
# Non-trainable params: 0
# _________________________________________________________________

# %%
#COMPILE THE MODEL

# %%
# Compile and fit
model.compile(
  loss='binary_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)


print('Training model...')
r = model.fit(
  data_train,
  Ytrain,
  epochs=15,
  validation_data=(data_test, Ytest)
)
# Out:
# Training model...
# Epoch 1/15
# 25/25 [==============================] - 4s 102ms/step - loss: 0.2131 - accuracy: 0.9613 - val_loss: 0.5251 - val_accuracy: 0.8150
# Epoch 2/15
# 25/25 [==============================] - 2s 91ms/step - loss: 0.1822 - accuracy: 0.9663 - val_loss: 0.5128 - val_accuracy: 0.8150
# Epoch 3/15
# 25/25 [==============================] - 2s 92ms/step - loss: 0.1635 - accuracy: 0.9663 - val_loss: 0.4908 - val_accuracy: 0.8150
# Epoch 4/15
# 25/25 [==============================] - 2s 92ms/step - loss: 0.1514 - accuracy: 0.9663 - val_loss: 0.5071 - val_accuracy: 0.8150
# Epoch 5/15
# 25/25 [==============================] - 2s 93ms/step - loss: 0.1307 - accuracy: 0.9762 - val_loss: 0.5200 - val_accuracy: 0.8150
# Epoch 6/15
# 25/25 [==============================] - 2s 92ms/step - loss: 0.1222 - accuracy: 0.9800 - val_loss: 0.5453 - val_accuracy: 0.8000
# Epoch 7/15
# 25/25 [==============================] - 2s 93ms/step - loss: 0.1072 - accuracy: 0.9800 - val_loss: 0.5285 - val_accuracy: 0.8200
# Epoch 8/15
# 25/25 [==============================] - 2s 93ms/step - loss: 0.1100 - accuracy: 0.9775 - val_loss: 0.5231 - val_accuracy: 0.8200
# Epoch 9/15
# 25/25 [==============================] - 2s 94ms/step - loss: 0.0927 - accuracy: 0.9787 - val_loss: 0.6137 - val_accuracy: 0.8200
# Epoch 10/15
# 25/25 [==============================] - 2s 92ms/step - loss: 0.0838 - accuracy: 0.9837 - val_loss: 0.5653 - val_accuracy: 0.8150
# Epoch 11/15
# 25/25 [==============================] - 2s 92ms/step - loss: 0.0764 - accuracy: 0.9850 - val_loss: 0.5699 - val_accuracy: 0.8200
# Epoch 12/15
# 25/25 [==============================] - 2s 92ms/step - loss: 0.0698 - accuracy: 0.9862 - val_loss: 0.6320 - val_accuracy: 0.7950
# Epoch 13/15
# 25/25 [==============================] - 2s 93ms/step - loss: 0.0658 - accuracy: 0.9875 - val_loss: 0.5886 - val_accuracy: 0.8200
# Epoch 14/15
# 25/25 [==============================] - 2s 93ms/step - loss: 0.0641 - accuracy: 0.9875 - val_loss: 0.6458 - val_accuracy: 0.8100
# Epoch 15/15
# 25/25 [==============================] - 2s 94ms/step - loss: 0.0552 - accuracy: 0.9887 - val_loss: 0.6231 - val_accuracy: 0.8150

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,5))


plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss' , color="red")
plt.grid()
plt.legend()

# %%
plt.figure(figsize=(10,5))

plt.plot(r.history['accuracy'], label='acc')
plt.plot(r.history['val_accuracy'], label='val_acc',color="red")
plt.grid()
plt.legend()

# %%
#LETS PREDICT IT .. FUN PART

# %%
#Reset the index in test data

# %%
df_test
# Out:
# 501      my late husband was my soulmate and he passe...
# 385     My mother and stepfather are coming to help m...
# 327       Today we got into an argument and it escala...
# 535    I have an abusive older brother (in his early ...
# 826     We started arguing then he choked me and I co...
#                              ...
# 531      I don't know where else to spill these feelings
# 156       I told him I've been getting sexually abuse...
# 513     I want to take some action against him but my...
# 544     I am a 22 year old girl and my last relations...
# 62     I know there easy answer is to block him but m...
# Name: data, Length: 200, dtype: object

# %%
df_test2=df_test.reset_index()

# %%
df_test2=df_test2.drop(columns=["index"])

# %%
df_test2.shape
# Out:
# (200, 1)

# %%
#exploration

# %%
df_test2.loc[38]
# Out:
# data    Hi guys
# Name: 38, dtype: object

# %%
df_test2.loc[38][0]
# Out:
# 'Hi guys'

# %%
Ytest.shape
# Out:
# (200,)

# %%
Ytest[38]
# Out:
# 0

# %%
#indexes for all the spam

# %%
np.where(Ytest==1)
# Out:
# (array([  1,   2,   3,   4,   6,   8,   9,  14,  15,  22,  24,  25,  28,
#          30,  32,  37,  40,  44,  45,  46,  49,  50,  51,  52,  53,  56,
#          59,  61,  64,  66,  67,  68,  71,  72,  73,  74,  76,  77,  80,
#          81,  83,  87,  89,  91,  92,  94,  99, 100, 102, 105, 106, 107,
#         108, 109, 110, 114, 121, 122, 123, 124, 127, 129, 130, 134, 136,
#         138, 139, 142, 147, 149, 150, 151, 155, 157, 158, 161, 166, 167,
#         172, 173, 176, 177, 178, 180, 181, 182, 184, 185, 186, 189, 191,
#         192, 196, 197, 199]),)

# %%
Ytest[45]
# Out:
# 1

# %%
df_test2.loc[1]
# Out:
# data     My mother and stepfather are coming to help m...
# Name: 1, dtype: object
